# %% [markdown]
# ## xckd-scraper.py
#
# Le but de ce notebook est de montrer un script de récupération de données provenant d'une source tierce (ici la liste des épisodes du webcomic XKCD), et leur transformation dans un format reconnu par l'un des outils d'imports de Wikidata (en l'occurrence Quick Statements.)
#
# ![XKCD - Manifestant wikipédien](https://upload.wikimedia.org/wikipedia/commons/7/77/Ref_necessaire.png)

# %%
import requests  # Librairie pour faire une requête web
from bs4 import BeautifulSoup  # Librairie pour interpréter une page web
from SPARQLWrapper import SPARQLWrapper, JSON  # Librairie pour faire une requête SPARQL

# Liste des langues pour lesquelles on va générer les libellés
languages = ['fr', 'en', 'br', 'de']

"""
Fonction pour faire une requête SPARQL sur le point d'accès de Wikidata
et renvoyer le résultat sous la forme d'un dictionnaire Python
"""
def wikidata_sparql_query(query):
    endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)

    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results

"""
Fonction qui renvoie la valeure ordinale en anglais d'un nombre positif ou nul
(par exemple, 1 → 1st, 2 → 2nd, 3 → 3rd, 4 → 4th)
Utilisé pour la description en anglais
"""
def ordinal(value):
    """
    Converts zero or a *positive* integer (or its string
    representation) to an ordinal value.
    """
    try:
        value = int(value)
    except ValueError:
        return value

    if value % 100 // 10 != 1:
        if value % 10 == 1:
            ordval = u"%d%s" % (value, "st")
        elif value % 10 == 2:
            ordval = u"%d%s" % (value, "nd")
        elif value % 10 == 3:
            ordval = u"%d%s" % (value, "rd")
        else:
            ordval = u"%d%s" % (value, "th")
    else:
        ordval = u"%d%s" % (value, "th")

    return ordval

"""
Fonction qui renvoie une déclaration avec sa propriété, sa valeur et
sa source au format attendu par QuickStatements
"""
def statement(prop, value, source):
    return "LAST\t{}\t{}\tS854\t\"{}\"".format(prop, value, source)


"""
Première étape : récupérer la liste des épisodes déjà présents sur Wikidata, pour
ne pas les importer à nouveau. On le fait par le biais d'une requête SPARQL
"""

imported_episodes = []

results = wikidata_sparql_query("""
SELECT DISTINCT ?episode ?episodeLabel ?number WHERE {
  # ?episode wdt:P31 wd:Q838795 .
  # ?episode wdt:P361 wd:Q13915 .
  # ?episode wdt:P433 ?number .

  SERVICE wikibase:label {
    bd:serviceParam wikibase:language "en" .
  }
} ORDER BY xsd:integer(?number)
""")

for r in results["results"]["bindings"]:
    try:
        imported_episodes.append(int(r["number"]["value"]))
    except:
        print("{} has no episode number.".format(r))

# On récupère le numéro d'épisode le plus élevé présent sur Wikidata
latest_imported_episode = max(imported_episodes)

# On vérifie qu'il ne manque pas d'épisodes avant celui-là...
for i in range(1, latest_imported_episode):
    # Sachant qu'il n'y a pas d'épisode 404.
    if i not in imported_episodes and i != 404:
        print('Episode {} is missing :('.format(i))


# On récupère la liste des épisodes sur le site xkcd
root_url = 'http://www.xkcd.com'
index_url = root_url + '/archive/index.html'

response = requests.get(index_url)
soup = BeautifulSoup(response.text, "lxml")

episodes = soup.select('div#middleContainer a')
episodes.reverse()

for e in episodes:
    # Récupération des données de base
    title = "\"" + e.get_text() + "\"" or ""
    urlbit = e.attrs.get('href') or ""
    episode_url = root_url + urlbit
    episodenumber = urlbit.replace("/", "")
    
    # Si l'épisode n'existe pas , on le crée
    if int(episodenumber) > latest_imported_episode:

        date = "+0000000" + '-'.join([
            "{0:0>2}".format(v) for v in e.attrs.get('title').split("-")]) + \
            "T00:00:00Z/11" or ""

        print("CREATE")
        for l in languages:
            print("LAST\tL{}\t{}".format(l, title))
            print("LAST\tA{}\t\"xkcd {}\"".format(l, episodenumber))

        print("LAST\tDfr\t\"strip de xkcd n°{}\"".format(episodenumber))
        print("LAST\tDde\t\"Folge des Webcomics xkcd\"")
        print("LAST\tDen\t\"{} strip of the webcomic xkcd\"".format(
            ordinal(episodenumber)))

        print(statement("P31", "Q838795", episode_url))  # instance of
        print(statement("P361", "Q13915", episode_url))  # part of        
        print(statement("P433", '"' + episodenumber + '"', episode_url))  # nb
        print(statement("P577", date, episode_url))  # date
        print(statement("P50", "Q285048", episode_url))  # Author: R. Munroe
        print(statement("P2699", '"' + episode_url + '"', episode_url))  # URL
        print(statement("P364", "Q1860", episode_url))  # Language: English
        print(statement("P275", "Q6936496", episode_url))  # Licence: CC-BY-NC
        print("")
# Out:
# CREATE
# LAST	Lfr	"Thumb War"
# LAST	Afr	"xkcd 1753"
# LAST	Len	"Thumb War"
# LAST	Aen	"xkcd 1753"
# LAST	Lbr	"Thumb War"
# LAST	Abr	"xkcd 1753"
# LAST	Lde	"Thumb War"
# LAST	Ade	"xkcd 1753"
# LAST	Dfr	"strip de xkcd n°1753"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1753rd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1753/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1753/"
# LAST	P433	"1753"	S854	"http://www.xkcd.com/1753/"
# LAST	P577	+00000002016-10-31T00:00:00Z/11	S854	"http://www.xkcd.com/1753/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1753/"
# LAST	P2699	"http://www.xkcd.com/1753/"	S854	"http://www.xkcd.com/1753/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1753/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1753/"
#
# CREATE
# LAST	Lfr	"Tornado Safety Tips"
# LAST	Afr	"xkcd 1754"
# LAST	Len	"Tornado Safety Tips"
# LAST	Aen	"xkcd 1754"
# LAST	Lbr	"Tornado Safety Tips"
# LAST	Abr	"xkcd 1754"
# LAST	Lde	"Tornado Safety Tips"
# LAST	Ade	"xkcd 1754"
# LAST	Dfr	"strip de xkcd n°1754"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1754th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1754/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1754/"
# LAST	P433	"1754"	S854	"http://www.xkcd.com/1754/"
# LAST	P577	+00000002016-11-02T00:00:00Z/11	S854	"http://www.xkcd.com/1754/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1754/"
# LAST	P2699	"http://www.xkcd.com/1754/"	S854	"http://www.xkcd.com/1754/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1754/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1754/"
#
# CREATE
# LAST	Lfr	"Old Days"
# LAST	Afr	"xkcd 1755"
# LAST	Len	"Old Days"
# LAST	Aen	"xkcd 1755"
# LAST	Lbr	"Old Days"
# LAST	Abr	"xkcd 1755"
# LAST	Lde	"Old Days"
# LAST	Ade	"xkcd 1755"
# LAST	Dfr	"strip de xkcd n°1755"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1755th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1755/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1755/"
# LAST	P433	"1755"	S854	"http://www.xkcd.com/1755/"
# LAST	P577	+00000002016-11-04T00:00:00Z/11	S854	"http://www.xkcd.com/1755/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1755/"
# LAST	P2699	"http://www.xkcd.com/1755/"	S854	"http://www.xkcd.com/1755/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1755/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1755/"
#
# CREATE
# LAST	Lfr	"I'm With Her"
# LAST	Afr	"xkcd 1756"
# LAST	Len	"I'm With Her"
# LAST	Aen	"xkcd 1756"
# LAST	Lbr	"I'm With Her"
# LAST	Abr	"xkcd 1756"
# LAST	Lde	"I'm With Her"
# LAST	Ade	"xkcd 1756"
# LAST	Dfr	"strip de xkcd n°1756"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1756th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1756/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1756/"
# LAST	P433	"1756"	S854	"http://www.xkcd.com/1756/"
# LAST	P577	+00000002016-11-07T00:00:00Z/11	S854	"http://www.xkcd.com/1756/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1756/"
# LAST	P2699	"http://www.xkcd.com/1756/"	S854	"http://www.xkcd.com/1756/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1756/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1756/"
#
# CREATE
# LAST	Lfr	"November 2016"
# LAST	Afr	"xkcd 1757"
# LAST	Len	"November 2016"
# LAST	Aen	"xkcd 1757"
# LAST	Lbr	"November 2016"
# LAST	Abr	"xkcd 1757"
# LAST	Lde	"November 2016"
# LAST	Ade	"xkcd 1757"
# LAST	Dfr	"strip de xkcd n°1757"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1757th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1757/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1757/"
# LAST	P433	"1757"	S854	"http://www.xkcd.com/1757/"
# LAST	P577	+00000002016-11-09T00:00:00Z/11	S854	"http://www.xkcd.com/1757/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1757/"
# LAST	P2699	"http://www.xkcd.com/1757/"	S854	"http://www.xkcd.com/1757/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1757/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1757/"
#
# CREATE
# LAST	Lfr	"Astrophysics"
# LAST	Afr	"xkcd 1758"
# LAST	Len	"Astrophysics"
# LAST	Aen	"xkcd 1758"
# LAST	Lbr	"Astrophysics"
# LAST	Abr	"xkcd 1758"
# LAST	Lde	"Astrophysics"
# LAST	Ade	"xkcd 1758"
# LAST	Dfr	"strip de xkcd n°1758"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1758th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1758/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1758/"
# LAST	P433	"1758"	S854	"http://www.xkcd.com/1758/"
# LAST	P577	+00000002016-11-11T00:00:00Z/11	S854	"http://www.xkcd.com/1758/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1758/"
# LAST	P2699	"http://www.xkcd.com/1758/"	S854	"http://www.xkcd.com/1758/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1758/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1758/"
#
# CREATE
# LAST	Lfr	"British Map"
# LAST	Afr	"xkcd 1759"
# LAST	Len	"British Map"
# LAST	Aen	"xkcd 1759"
# LAST	Lbr	"British Map"
# LAST	Abr	"xkcd 1759"
# LAST	Lde	"British Map"
# LAST	Ade	"xkcd 1759"
# LAST	Dfr	"strip de xkcd n°1759"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1759th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1759/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1759/"
# LAST	P433	"1759"	S854	"http://www.xkcd.com/1759/"
# LAST	P577	+00000002016-11-14T00:00:00Z/11	S854	"http://www.xkcd.com/1759/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1759/"
# LAST	P2699	"http://www.xkcd.com/1759/"	S854	"http://www.xkcd.com/1759/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1759/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1759/"
#
# CREATE
# LAST	Lfr	"TV Problems"
# LAST	Afr	"xkcd 1760"
# LAST	Len	"TV Problems"
# LAST	Aen	"xkcd 1760"
# LAST	Lbr	"TV Problems"
# LAST	Abr	"xkcd 1760"
# LAST	Lde	"TV Problems"
# LAST	Ade	"xkcd 1760"
# LAST	Dfr	"strip de xkcd n°1760"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1760th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1760/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1760/"
# LAST	P433	"1760"	S854	"http://www.xkcd.com/1760/"
# LAST	P577	+00000002016-11-16T00:00:00Z/11	S854	"http://www.xkcd.com/1760/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1760/"
# LAST	P2699	"http://www.xkcd.com/1760/"	S854	"http://www.xkcd.com/1760/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1760/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1760/"
#
# CREATE
# LAST	Lfr	"Blame"
# LAST	Afr	"xkcd 1761"
# LAST	Len	"Blame"
# LAST	Aen	"xkcd 1761"
# LAST	Lbr	"Blame"
# LAST	Abr	"xkcd 1761"
# LAST	Lde	"Blame"
# LAST	Ade	"xkcd 1761"
# LAST	Dfr	"strip de xkcd n°1761"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1761st strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1761/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1761/"
# LAST	P433	"1761"	S854	"http://www.xkcd.com/1761/"
# LAST	P577	+00000002016-11-18T00:00:00Z/11	S854	"http://www.xkcd.com/1761/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1761/"
# LAST	P2699	"http://www.xkcd.com/1761/"	S854	"http://www.xkcd.com/1761/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1761/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1761/"
#
# CREATE
# LAST	Lfr	"Moving Boxes"
# LAST	Afr	"xkcd 1762"
# LAST	Len	"Moving Boxes"
# LAST	Aen	"xkcd 1762"
# LAST	Lbr	"Moving Boxes"
# LAST	Abr	"xkcd 1762"
# LAST	Lde	"Moving Boxes"
# LAST	Ade	"xkcd 1762"
# LAST	Dfr	"strip de xkcd n°1762"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1762nd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1762/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1762/"
# LAST	P433	"1762"	S854	"http://www.xkcd.com/1762/"
# LAST	P577	+00000002016-11-21T00:00:00Z/11	S854	"http://www.xkcd.com/1762/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1762/"
# LAST	P2699	"http://www.xkcd.com/1762/"	S854	"http://www.xkcd.com/1762/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1762/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1762/"
#
# CREATE
# LAST	Lfr	"Catcalling"
# LAST	Afr	"xkcd 1763"
# LAST	Len	"Catcalling"
# LAST	Aen	"xkcd 1763"
# LAST	Lbr	"Catcalling"
# LAST	Abr	"xkcd 1763"
# LAST	Lde	"Catcalling"
# LAST	Ade	"xkcd 1763"
# LAST	Dfr	"strip de xkcd n°1763"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1763rd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1763/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1763/"
# LAST	P433	"1763"	S854	"http://www.xkcd.com/1763/"
# LAST	P577	+00000002016-11-23T00:00:00Z/11	S854	"http://www.xkcd.com/1763/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1763/"
# LAST	P2699	"http://www.xkcd.com/1763/"	S854	"http://www.xkcd.com/1763/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1763/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1763/"
#
# CREATE
# LAST	Lfr	"XKCDE"
# LAST	Afr	"xkcd 1764"
# LAST	Len	"XKCDE"
# LAST	Aen	"xkcd 1764"
# LAST	Lbr	"XKCDE"
# LAST	Abr	"xkcd 1764"
# LAST	Lde	"XKCDE"
# LAST	Ade	"xkcd 1764"
# LAST	Dfr	"strip de xkcd n°1764"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1764th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1764/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1764/"
# LAST	P433	"1764"	S854	"http://www.xkcd.com/1764/"
# LAST	P577	+00000002016-11-25T00:00:00Z/11	S854	"http://www.xkcd.com/1764/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1764/"
# LAST	P2699	"http://www.xkcd.com/1764/"	S854	"http://www.xkcd.com/1764/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1764/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1764/"
#
# CREATE
# LAST	Lfr	"Baby Post"
# LAST	Afr	"xkcd 1765"
# LAST	Len	"Baby Post"
# LAST	Aen	"xkcd 1765"
# LAST	Lbr	"Baby Post"
# LAST	Abr	"xkcd 1765"
# LAST	Lde	"Baby Post"
# LAST	Ade	"xkcd 1765"
# LAST	Dfr	"strip de xkcd n°1765"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1765th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1765/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1765/"
# LAST	P433	"1765"	S854	"http://www.xkcd.com/1765/"
# LAST	P577	+00000002016-11-28T00:00:00Z/11	S854	"http://www.xkcd.com/1765/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1765/"
# LAST	P2699	"http://www.xkcd.com/1765/"	S854	"http://www.xkcd.com/1765/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1765/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1765/"
#
# CREATE
# LAST	Lfr	"Apple Spectrum"
# LAST	Afr	"xkcd 1766"
# LAST	Len	"Apple Spectrum"
# LAST	Aen	"xkcd 1766"
# LAST	Lbr	"Apple Spectrum"
# LAST	Abr	"xkcd 1766"
# LAST	Lde	"Apple Spectrum"
# LAST	Ade	"xkcd 1766"
# LAST	Dfr	"strip de xkcd n°1766"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1766th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1766/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1766/"
# LAST	P433	"1766"	S854	"http://www.xkcd.com/1766/"
# LAST	P577	+00000002016-11-30T00:00:00Z/11	S854	"http://www.xkcd.com/1766/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1766/"
# LAST	P2699	"http://www.xkcd.com/1766/"	S854	"http://www.xkcd.com/1766/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1766/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1766/"
#
# CREATE
# LAST	Lfr	"US State Names"
# LAST	Afr	"xkcd 1767"
# LAST	Len	"US State Names"
# LAST	Aen	"xkcd 1767"
# LAST	Lbr	"US State Names"
# LAST	Abr	"xkcd 1767"
# LAST	Lde	"US State Names"
# LAST	Ade	"xkcd 1767"
# LAST	Dfr	"strip de xkcd n°1767"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1767th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1767/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1767/"
# LAST	P433	"1767"	S854	"http://www.xkcd.com/1767/"
# LAST	P577	+00000002016-12-02T00:00:00Z/11	S854	"http://www.xkcd.com/1767/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1767/"
# LAST	P2699	"http://www.xkcd.com/1767/"	S854	"http://www.xkcd.com/1767/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1767/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1767/"
#
# CREATE
# LAST	Lfr	"Settling"
# LAST	Afr	"xkcd 1768"
# LAST	Len	"Settling"
# LAST	Aen	"xkcd 1768"
# LAST	Lbr	"Settling"
# LAST	Abr	"xkcd 1768"
# LAST	Lde	"Settling"
# LAST	Ade	"xkcd 1768"
# LAST	Dfr	"strip de xkcd n°1768"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1768th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1768/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1768/"
# LAST	P433	"1768"	S854	"http://www.xkcd.com/1768/"
# LAST	P577	+00000002016-12-05T00:00:00Z/11	S854	"http://www.xkcd.com/1768/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1768/"
# LAST	P2699	"http://www.xkcd.com/1768/"	S854	"http://www.xkcd.com/1768/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1768/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1768/"
#
# CREATE
# LAST	Lfr	"Never Seen Star Wars"
# LAST	Afr	"xkcd 1769"
# LAST	Len	"Never Seen Star Wars"
# LAST	Aen	"xkcd 1769"
# LAST	Lbr	"Never Seen Star Wars"
# LAST	Abr	"xkcd 1769"
# LAST	Lde	"Never Seen Star Wars"
# LAST	Ade	"xkcd 1769"
# LAST	Dfr	"strip de xkcd n°1769"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1769th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1769/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1769/"
# LAST	P433	"1769"	S854	"http://www.xkcd.com/1769/"
# LAST	P577	+00000002016-12-07T00:00:00Z/11	S854	"http://www.xkcd.com/1769/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1769/"
# LAST	P2699	"http://www.xkcd.com/1769/"	S854	"http://www.xkcd.com/1769/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1769/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1769/"
#
# CREATE
# LAST	Lfr	"UI Change"
# LAST	Afr	"xkcd 1770"
# LAST	Len	"UI Change"
# LAST	Aen	"xkcd 1770"
# LAST	Lbr	"UI Change"
# LAST	Abr	"xkcd 1770"
# LAST	Lde	"UI Change"
# LAST	Ade	"xkcd 1770"
# LAST	Dfr	"strip de xkcd n°1770"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1770th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1770/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1770/"
# LAST	P433	"1770"	S854	"http://www.xkcd.com/1770/"
# LAST	P577	+00000002016-12-09T00:00:00Z/11	S854	"http://www.xkcd.com/1770/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1770/"
# LAST	P2699	"http://www.xkcd.com/1770/"	S854	"http://www.xkcd.com/1770/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1770/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1770/"
#
# CREATE
# LAST	Lfr	"It Was I"
# LAST	Afr	"xkcd 1771"
# LAST	Len	"It Was I"
# LAST	Aen	"xkcd 1771"
# LAST	Lbr	"It Was I"
# LAST	Abr	"xkcd 1771"
# LAST	Lde	"It Was I"
# LAST	Ade	"xkcd 1771"
# LAST	Dfr	"strip de xkcd n°1771"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1771st strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1771/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1771/"
# LAST	P433	"1771"	S854	"http://www.xkcd.com/1771/"
# LAST	P577	+00000002016-12-12T00:00:00Z/11	S854	"http://www.xkcd.com/1771/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1771/"
# LAST	P2699	"http://www.xkcd.com/1771/"	S854	"http://www.xkcd.com/1771/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1771/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1771/"
#
# CREATE
# LAST	Lfr	"Startup Opportunity"
# LAST	Afr	"xkcd 1772"
# LAST	Len	"Startup Opportunity"
# LAST	Aen	"xkcd 1772"
# LAST	Lbr	"Startup Opportunity"
# LAST	Abr	"xkcd 1772"
# LAST	Lde	"Startup Opportunity"
# LAST	Ade	"xkcd 1772"
# LAST	Dfr	"strip de xkcd n°1772"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1772nd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1772/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1772/"
# LAST	P433	"1772"	S854	"http://www.xkcd.com/1772/"
# LAST	P577	+00000002016-12-14T00:00:00Z/11	S854	"http://www.xkcd.com/1772/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1772/"
# LAST	P2699	"http://www.xkcd.com/1772/"	S854	"http://www.xkcd.com/1772/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1772/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1772/"
#
# CREATE
# LAST	Lfr	"Negativity"
# LAST	Afr	"xkcd 1773"
# LAST	Len	"Negativity"
# LAST	Aen	"xkcd 1773"
# LAST	Lbr	"Negativity"
# LAST	Abr	"xkcd 1773"
# LAST	Lde	"Negativity"
# LAST	Ade	"xkcd 1773"
# LAST	Dfr	"strip de xkcd n°1773"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1773rd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1773/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1773/"
# LAST	P433	"1773"	S854	"http://www.xkcd.com/1773/"
# LAST	P577	+00000002016-12-16T00:00:00Z/11	S854	"http://www.xkcd.com/1773/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1773/"
# LAST	P2699	"http://www.xkcd.com/1773/"	S854	"http://www.xkcd.com/1773/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1773/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1773/"
#
# CREATE
# LAST	Lfr	"Adjective Foods"
# LAST	Afr	"xkcd 1774"
# LAST	Len	"Adjective Foods"
# LAST	Aen	"xkcd 1774"
# LAST	Lbr	"Adjective Foods"
# LAST	Abr	"xkcd 1774"
# LAST	Lde	"Adjective Foods"
# LAST	Ade	"xkcd 1774"
# LAST	Dfr	"strip de xkcd n°1774"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1774th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1774/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1774/"
# LAST	P433	"1774"	S854	"http://www.xkcd.com/1774/"
# LAST	P577	+00000002016-12-19T00:00:00Z/11	S854	"http://www.xkcd.com/1774/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1774/"
# LAST	P2699	"http://www.xkcd.com/1774/"	S854	"http://www.xkcd.com/1774/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1774/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1774/"
#
# CREATE
# LAST	Lfr	"Things You Learn"
# LAST	Afr	"xkcd 1775"
# LAST	Len	"Things You Learn"
# LAST	Aen	"xkcd 1775"
# LAST	Lbr	"Things You Learn"
# LAST	Abr	"xkcd 1775"
# LAST	Lde	"Things You Learn"
# LAST	Ade	"xkcd 1775"
# LAST	Dfr	"strip de xkcd n°1775"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1775th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1775/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1775/"
# LAST	P433	"1775"	S854	"http://www.xkcd.com/1775/"
# LAST	P577	+00000002016-12-21T00:00:00Z/11	S854	"http://www.xkcd.com/1775/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1775/"
# LAST	P2699	"http://www.xkcd.com/1775/"	S854	"http://www.xkcd.com/1775/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1775/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1775/"
#
# CREATE
# LAST	Lfr	"Reindeer"
# LAST	Afr	"xkcd 1776"
# LAST	Len	"Reindeer"
# LAST	Aen	"xkcd 1776"
# LAST	Lbr	"Reindeer"
# LAST	Abr	"xkcd 1776"
# LAST	Lde	"Reindeer"
# LAST	Ade	"xkcd 1776"
# LAST	Dfr	"strip de xkcd n°1776"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1776th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1776/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1776/"
# LAST	P433	"1776"	S854	"http://www.xkcd.com/1776/"
# LAST	P577	+00000002016-12-23T00:00:00Z/11	S854	"http://www.xkcd.com/1776/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1776/"
# LAST	P2699	"http://www.xkcd.com/1776/"	S854	"http://www.xkcd.com/1776/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1776/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1776/"
#
# CREATE
# LAST	Lfr	"Dear Diary"
# LAST	Afr	"xkcd 1777"
# LAST	Len	"Dear Diary"
# LAST	Aen	"xkcd 1777"
# LAST	Lbr	"Dear Diary"
# LAST	Abr	"xkcd 1777"
# LAST	Lde	"Dear Diary"
# LAST	Ade	"xkcd 1777"
# LAST	Dfr	"strip de xkcd n°1777"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1777th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1777/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1777/"
# LAST	P433	"1777"	S854	"http://www.xkcd.com/1777/"
# LAST	P577	+00000002016-12-26T00:00:00Z/11	S854	"http://www.xkcd.com/1777/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1777/"
# LAST	P2699	"http://www.xkcd.com/1777/"	S854	"http://www.xkcd.com/1777/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1777/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1777/"
#
# CREATE
# LAST	Lfr	"Interest Timescales"
# LAST	Afr	"xkcd 1778"
# LAST	Len	"Interest Timescales"
# LAST	Aen	"xkcd 1778"
# LAST	Lbr	"Interest Timescales"
# LAST	Abr	"xkcd 1778"
# LAST	Lde	"Interest Timescales"
# LAST	Ade	"xkcd 1778"
# LAST	Dfr	"strip de xkcd n°1778"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1778th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1778/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1778/"
# LAST	P433	"1778"	S854	"http://www.xkcd.com/1778/"
# LAST	P577	+00000002016-12-28T00:00:00Z/11	S854	"http://www.xkcd.com/1778/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1778/"
# LAST	P2699	"http://www.xkcd.com/1778/"	S854	"http://www.xkcd.com/1778/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1778/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1778/"
#
# CREATE
# LAST	Lfr	"2017"
# LAST	Afr	"xkcd 1779"
# LAST	Len	"2017"
# LAST	Aen	"xkcd 1779"
# LAST	Lbr	"2017"
# LAST	Abr	"xkcd 1779"
# LAST	Lde	"2017"
# LAST	Ade	"xkcd 1779"
# LAST	Dfr	"strip de xkcd n°1779"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1779th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1779/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1779/"
# LAST	P433	"1779"	S854	"http://www.xkcd.com/1779/"
# LAST	P577	+00000002016-12-30T00:00:00Z/11	S854	"http://www.xkcd.com/1779/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1779/"
# LAST	P2699	"http://www.xkcd.com/1779/"	S854	"http://www.xkcd.com/1779/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1779/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1779/"
#
# CREATE
# LAST	Lfr	"Appliance Repair"
# LAST	Afr	"xkcd 1780"
# LAST	Len	"Appliance Repair"
# LAST	Aen	"xkcd 1780"
# LAST	Lbr	"Appliance Repair"
# LAST	Abr	"xkcd 1780"
# LAST	Lde	"Appliance Repair"
# LAST	Ade	"xkcd 1780"
# LAST	Dfr	"strip de xkcd n°1780"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1780th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1780/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1780/"
# LAST	P433	"1780"	S854	"http://www.xkcd.com/1780/"
# LAST	P577	+00000002017-01-02T00:00:00Z/11	S854	"http://www.xkcd.com/1780/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1780/"
# LAST	P2699	"http://www.xkcd.com/1780/"	S854	"http://www.xkcd.com/1780/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1780/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1780/"
#
# CREATE
# LAST	Lfr	"Artifacts"
# LAST	Afr	"xkcd 1781"
# LAST	Len	"Artifacts"
# LAST	Aen	"xkcd 1781"
# LAST	Lbr	"Artifacts"
# LAST	Abr	"xkcd 1781"
# LAST	Lde	"Artifacts"
# LAST	Ade	"xkcd 1781"
# LAST	Dfr	"strip de xkcd n°1781"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1781st strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1781/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1781/"
# LAST	P433	"1781"	S854	"http://www.xkcd.com/1781/"
# LAST	P577	+00000002017-01-04T00:00:00Z/11	S854	"http://www.xkcd.com/1781/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1781/"
# LAST	P2699	"http://www.xkcd.com/1781/"	S854	"http://www.xkcd.com/1781/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1781/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1781/"
#
# CREATE
# LAST	Lfr	"Team Chat"
# LAST	Afr	"xkcd 1782"
# LAST	Len	"Team Chat"
# LAST	Aen	"xkcd 1782"
# LAST	Lbr	"Team Chat"
# LAST	Abr	"xkcd 1782"
# LAST	Lde	"Team Chat"
# LAST	Ade	"xkcd 1782"
# LAST	Dfr	"strip de xkcd n°1782"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1782nd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1782/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1782/"
# LAST	P433	"1782"	S854	"http://www.xkcd.com/1782/"
# LAST	P577	+00000002017-01-06T00:00:00Z/11	S854	"http://www.xkcd.com/1782/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1782/"
# LAST	P2699	"http://www.xkcd.com/1782/"	S854	"http://www.xkcd.com/1782/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1782/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1782/"
#
# CREATE
# LAST	Lfr	"Emails"
# LAST	Afr	"xkcd 1783"
# LAST	Len	"Emails"
# LAST	Aen	"xkcd 1783"
# LAST	Lbr	"Emails"
# LAST	Abr	"xkcd 1783"
# LAST	Lde	"Emails"
# LAST	Ade	"xkcd 1783"
# LAST	Dfr	"strip de xkcd n°1783"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1783rd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1783/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1783/"
# LAST	P433	"1783"	S854	"http://www.xkcd.com/1783/"
# LAST	P577	+00000002017-01-09T00:00:00Z/11	S854	"http://www.xkcd.com/1783/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1783/"
# LAST	P2699	"http://www.xkcd.com/1783/"	S854	"http://www.xkcd.com/1783/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1783/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1783/"
#
# CREATE
# LAST	Lfr	"Bad Map Projection: Liquid Resize"
# LAST	Afr	"xkcd 1784"
# LAST	Len	"Bad Map Projection: Liquid Resize"
# LAST	Aen	"xkcd 1784"
# LAST	Lbr	"Bad Map Projection: Liquid Resize"
# LAST	Abr	"xkcd 1784"
# LAST	Lde	"Bad Map Projection: Liquid Resize"
# LAST	Ade	"xkcd 1784"
# LAST	Dfr	"strip de xkcd n°1784"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1784th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1784/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1784/"
# LAST	P433	"1784"	S854	"http://www.xkcd.com/1784/"
# LAST	P577	+00000002017-01-11T00:00:00Z/11	S854	"http://www.xkcd.com/1784/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1784/"
# LAST	P2699	"http://www.xkcd.com/1784/"	S854	"http://www.xkcd.com/1784/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1784/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1784/"
#
# CREATE
# LAST	Lfr	"Wifi"
# LAST	Afr	"xkcd 1785"
# LAST	Len	"Wifi"
# LAST	Aen	"xkcd 1785"
# LAST	Lbr	"Wifi"
# LAST	Abr	"xkcd 1785"
# LAST	Lde	"Wifi"
# LAST	Ade	"xkcd 1785"
# LAST	Dfr	"strip de xkcd n°1785"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1785th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1785/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1785/"
# LAST	P433	"1785"	S854	"http://www.xkcd.com/1785/"
# LAST	P577	+00000002017-01-13T00:00:00Z/11	S854	"http://www.xkcd.com/1785/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1785/"
# LAST	P2699	"http://www.xkcd.com/1785/"	S854	"http://www.xkcd.com/1785/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1785/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1785/"
#
# CREATE
# LAST	Lfr	"Trash"
# LAST	Afr	"xkcd 1786"
# LAST	Len	"Trash"
# LAST	Aen	"xkcd 1786"
# LAST	Lbr	"Trash"
# LAST	Abr	"xkcd 1786"
# LAST	Lde	"Trash"
# LAST	Ade	"xkcd 1786"
# LAST	Dfr	"strip de xkcd n°1786"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1786th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1786/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1786/"
# LAST	P433	"1786"	S854	"http://www.xkcd.com/1786/"
# LAST	P577	+00000002017-01-16T00:00:00Z/11	S854	"http://www.xkcd.com/1786/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1786/"
# LAST	P2699	"http://www.xkcd.com/1786/"	S854	"http://www.xkcd.com/1786/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1786/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1786/"
#
# CREATE
# LAST	Lfr	"Voice Commands"
# LAST	Afr	"xkcd 1787"
# LAST	Len	"Voice Commands"
# LAST	Aen	"xkcd 1787"
# LAST	Lbr	"Voice Commands"
# LAST	Abr	"xkcd 1787"
# LAST	Lde	"Voice Commands"
# LAST	Ade	"xkcd 1787"
# LAST	Dfr	"strip de xkcd n°1787"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1787th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1787/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1787/"
# LAST	P433	"1787"	S854	"http://www.xkcd.com/1787/"
# LAST	P577	+00000002017-01-18T00:00:00Z/11	S854	"http://www.xkcd.com/1787/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1787/"
# LAST	P2699	"http://www.xkcd.com/1787/"	S854	"http://www.xkcd.com/1787/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1787/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1787/"
#
# CREATE
# LAST	Lfr	"Barge"
# LAST	Afr	"xkcd 1788"
# LAST	Len	"Barge"
# LAST	Aen	"xkcd 1788"
# LAST	Lbr	"Barge"
# LAST	Abr	"xkcd 1788"
# LAST	Lde	"Barge"
# LAST	Ade	"xkcd 1788"
# LAST	Dfr	"strip de xkcd n°1788"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1788th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1788/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1788/"
# LAST	P433	"1788"	S854	"http://www.xkcd.com/1788/"
# LAST	P577	+00000002017-01-20T00:00:00Z/11	S854	"http://www.xkcd.com/1788/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1788/"
# LAST	P2699	"http://www.xkcd.com/1788/"	S854	"http://www.xkcd.com/1788/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1788/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1788/"
#
# CREATE
# LAST	Lfr	"Phone Numbers"
# LAST	Afr	"xkcd 1789"
# LAST	Len	"Phone Numbers"
# LAST	Aen	"xkcd 1789"
# LAST	Lbr	"Phone Numbers"
# LAST	Abr	"xkcd 1789"
# LAST	Lde	"Phone Numbers"
# LAST	Ade	"xkcd 1789"
# LAST	Dfr	"strip de xkcd n°1789"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1789th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1789/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1789/"
# LAST	P433	"1789"	S854	"http://www.xkcd.com/1789/"
# LAST	P577	+00000002017-01-23T00:00:00Z/11	S854	"http://www.xkcd.com/1789/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1789/"
# LAST	P2699	"http://www.xkcd.com/1789/"	S854	"http://www.xkcd.com/1789/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1789/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1789/"
#
# CREATE
# LAST	Lfr	"Sad"
# LAST	Afr	"xkcd 1790"
# LAST	Len	"Sad"
# LAST	Aen	"xkcd 1790"
# LAST	Lbr	"Sad"
# LAST	Abr	"xkcd 1790"
# LAST	Lde	"Sad"
# LAST	Ade	"xkcd 1790"
# LAST	Dfr	"strip de xkcd n°1790"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1790th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1790/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1790/"
# LAST	P433	"1790"	S854	"http://www.xkcd.com/1790/"
# LAST	P577	+00000002017-01-25T00:00:00Z/11	S854	"http://www.xkcd.com/1790/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1790/"
# LAST	P2699	"http://www.xkcd.com/1790/"	S854	"http://www.xkcd.com/1790/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1790/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1790/"
#
# CREATE
# LAST	Lfr	"Telescopes: Refractor vs Reflector"
# LAST	Afr	"xkcd 1791"
# LAST	Len	"Telescopes: Refractor vs Reflector"
# LAST	Aen	"xkcd 1791"
# LAST	Lbr	"Telescopes: Refractor vs Reflector"
# LAST	Abr	"xkcd 1791"
# LAST	Lde	"Telescopes: Refractor vs Reflector"
# LAST	Ade	"xkcd 1791"
# LAST	Dfr	"strip de xkcd n°1791"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1791st strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1791/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1791/"
# LAST	P433	"1791"	S854	"http://www.xkcd.com/1791/"
# LAST	P577	+00000002017-01-27T00:00:00Z/11	S854	"http://www.xkcd.com/1791/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1791/"
# LAST	P2699	"http://www.xkcd.com/1791/"	S854	"http://www.xkcd.com/1791/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1791/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1791/"
#
# CREATE
# LAST	Lfr	"Bird/Plane/Superman"
# LAST	Afr	"xkcd 1792"
# LAST	Len	"Bird/Plane/Superman"
# LAST	Aen	"xkcd 1792"
# LAST	Lbr	"Bird/Plane/Superman"
# LAST	Abr	"xkcd 1792"
# LAST	Lde	"Bird/Plane/Superman"
# LAST	Ade	"xkcd 1792"
# LAST	Dfr	"strip de xkcd n°1792"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1792nd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1792/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1792/"
# LAST	P433	"1792"	S854	"http://www.xkcd.com/1792/"
# LAST	P577	+00000002017-01-30T00:00:00Z/11	S854	"http://www.xkcd.com/1792/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1792/"
# LAST	P2699	"http://www.xkcd.com/1792/"	S854	"http://www.xkcd.com/1792/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1792/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1792/"
#
# CREATE
# LAST	Lfr	"Soda Sugar Comparisons"
# LAST	Afr	"xkcd 1793"
# LAST	Len	"Soda Sugar Comparisons"
# LAST	Aen	"xkcd 1793"
# LAST	Lbr	"Soda Sugar Comparisons"
# LAST	Abr	"xkcd 1793"
# LAST	Lde	"Soda Sugar Comparisons"
# LAST	Ade	"xkcd 1793"
# LAST	Dfr	"strip de xkcd n°1793"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1793rd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1793/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1793/"
# LAST	P433	"1793"	S854	"http://www.xkcd.com/1793/"
# LAST	P577	+00000002017-02-01T00:00:00Z/11	S854	"http://www.xkcd.com/1793/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1793/"
# LAST	P2699	"http://www.xkcd.com/1793/"	S854	"http://www.xkcd.com/1793/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1793/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1793/"
#
# CREATE
# LAST	Lfr	"Fire"
# LAST	Afr	"xkcd 1794"
# LAST	Len	"Fire"
# LAST	Aen	"xkcd 1794"
# LAST	Lbr	"Fire"
# LAST	Abr	"xkcd 1794"
# LAST	Lde	"Fire"
# LAST	Ade	"xkcd 1794"
# LAST	Dfr	"strip de xkcd n°1794"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1794th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1794/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1794/"
# LAST	P433	"1794"	S854	"http://www.xkcd.com/1794/"
# LAST	P577	+00000002017-02-03T00:00:00Z/11	S854	"http://www.xkcd.com/1794/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1794/"
# LAST	P2699	"http://www.xkcd.com/1794/"	S854	"http://www.xkcd.com/1794/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1794/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1794/"
#
# CREATE
# LAST	Lfr	"All You Can Eat"
# LAST	Afr	"xkcd 1795"
# LAST	Len	"All You Can Eat"
# LAST	Aen	"xkcd 1795"
# LAST	Lbr	"All You Can Eat"
# LAST	Abr	"xkcd 1795"
# LAST	Lde	"All You Can Eat"
# LAST	Ade	"xkcd 1795"
# LAST	Dfr	"strip de xkcd n°1795"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1795th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1795/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1795/"
# LAST	P433	"1795"	S854	"http://www.xkcd.com/1795/"
# LAST	P577	+00000002017-02-06T00:00:00Z/11	S854	"http://www.xkcd.com/1795/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1795/"
# LAST	P2699	"http://www.xkcd.com/1795/"	S854	"http://www.xkcd.com/1795/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1795/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1795/"
#
# CREATE
# LAST	Lfr	"Focus Knob"
# LAST	Afr	"xkcd 1796"
# LAST	Len	"Focus Knob"
# LAST	Aen	"xkcd 1796"
# LAST	Lbr	"Focus Knob"
# LAST	Abr	"xkcd 1796"
# LAST	Lde	"Focus Knob"
# LAST	Ade	"xkcd 1796"
# LAST	Dfr	"strip de xkcd n°1796"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1796th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1796/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1796/"
# LAST	P433	"1796"	S854	"http://www.xkcd.com/1796/"
# LAST	P577	+00000002017-02-08T00:00:00Z/11	S854	"http://www.xkcd.com/1796/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1796/"
# LAST	P2699	"http://www.xkcd.com/1796/"	S854	"http://www.xkcd.com/1796/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1796/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1796/"
#
# CREATE
# LAST	Lfr	"Stardew Valley"
# LAST	Afr	"xkcd 1797"
# LAST	Len	"Stardew Valley"
# LAST	Aen	"xkcd 1797"
# LAST	Lbr	"Stardew Valley"
# LAST	Abr	"xkcd 1797"
# LAST	Lde	"Stardew Valley"
# LAST	Ade	"xkcd 1797"
# LAST	Dfr	"strip de xkcd n°1797"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1797th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1797/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1797/"
# LAST	P433	"1797"	S854	"http://www.xkcd.com/1797/"
# LAST	P577	+00000002017-02-10T00:00:00Z/11	S854	"http://www.xkcd.com/1797/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1797/"
# LAST	P2699	"http://www.xkcd.com/1797/"	S854	"http://www.xkcd.com/1797/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1797/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1797/"
#
# CREATE
# LAST	Lfr	"Box Plot"
# LAST	Afr	"xkcd 1798"
# LAST	Len	"Box Plot"
# LAST	Aen	"xkcd 1798"
# LAST	Lbr	"Box Plot"
# LAST	Abr	"xkcd 1798"
# LAST	Lde	"Box Plot"
# LAST	Ade	"xkcd 1798"
# LAST	Dfr	"strip de xkcd n°1798"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1798th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1798/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1798/"
# LAST	P433	"1798"	S854	"http://www.xkcd.com/1798/"
# LAST	P577	+00000002017-02-13T00:00:00Z/11	S854	"http://www.xkcd.com/1798/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1798/"
# LAST	P2699	"http://www.xkcd.com/1798/"	S854	"http://www.xkcd.com/1798/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1798/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1798/"
#
# CREATE
# LAST	Lfr	"Bad Map Projection: Time Zones"
# LAST	Afr	"xkcd 1799"
# LAST	Len	"Bad Map Projection: Time Zones"
# LAST	Aen	"xkcd 1799"
# LAST	Lbr	"Bad Map Projection: Time Zones"
# LAST	Abr	"xkcd 1799"
# LAST	Lde	"Bad Map Projection: Time Zones"
# LAST	Ade	"xkcd 1799"
# LAST	Dfr	"strip de xkcd n°1799"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1799th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1799/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1799/"
# LAST	P433	"1799"	S854	"http://www.xkcd.com/1799/"
# LAST	P577	+00000002017-02-15T00:00:00Z/11	S854	"http://www.xkcd.com/1799/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1799/"
# LAST	P2699	"http://www.xkcd.com/1799/"	S854	"http://www.xkcd.com/1799/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1799/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1799/"
#
# CREATE
# LAST	Lfr	"Chess Notation"
# LAST	Afr	"xkcd 1800"
# LAST	Len	"Chess Notation"
# LAST	Aen	"xkcd 1800"
# LAST	Lbr	"Chess Notation"
# LAST	Abr	"xkcd 1800"
# LAST	Lde	"Chess Notation"
# LAST	Ade	"xkcd 1800"
# LAST	Dfr	"strip de xkcd n°1800"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1800th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1800/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1800/"
# LAST	P433	"1800"	S854	"http://www.xkcd.com/1800/"
# LAST	P577	+00000002017-02-17T00:00:00Z/11	S854	"http://www.xkcd.com/1800/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1800/"
# LAST	P2699	"http://www.xkcd.com/1800/"	S854	"http://www.xkcd.com/1800/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1800/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1800/"
#
# CREATE
# LAST	Lfr	"Decision Paralysis"
# LAST	Afr	"xkcd 1801"
# LAST	Len	"Decision Paralysis"
# LAST	Aen	"xkcd 1801"
# LAST	Lbr	"Decision Paralysis"
# LAST	Abr	"xkcd 1801"
# LAST	Lde	"Decision Paralysis"
# LAST	Ade	"xkcd 1801"
# LAST	Dfr	"strip de xkcd n°1801"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1801st strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1801/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1801/"
# LAST	P433	"1801"	S854	"http://www.xkcd.com/1801/"
# LAST	P577	+00000002017-02-20T00:00:00Z/11	S854	"http://www.xkcd.com/1801/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1801/"
# LAST	P2699	"http://www.xkcd.com/1801/"	S854	"http://www.xkcd.com/1801/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1801/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1801/"
#
# CREATE
# LAST	Lfr	"Phone"
# LAST	Afr	"xkcd 1802"
# LAST	Len	"Phone"
# LAST	Aen	"xkcd 1802"
# LAST	Lbr	"Phone"
# LAST	Abr	"xkcd 1802"
# LAST	Lde	"Phone"
# LAST	Ade	"xkcd 1802"
# LAST	Dfr	"strip de xkcd n°1802"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1802nd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1802/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1802/"
# LAST	P433	"1802"	S854	"http://www.xkcd.com/1802/"
# LAST	P577	+00000002017-02-22T00:00:00Z/11	S854	"http://www.xkcd.com/1802/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1802/"
# LAST	P2699	"http://www.xkcd.com/1802/"	S854	"http://www.xkcd.com/1802/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1802/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1802/"
#
# CREATE
# LAST	Lfr	"Location Reviews"
# LAST	Afr	"xkcd 1803"
# LAST	Len	"Location Reviews"
# LAST	Aen	"xkcd 1803"
# LAST	Lbr	"Location Reviews"
# LAST	Abr	"xkcd 1803"
# LAST	Lde	"Location Reviews"
# LAST	Ade	"xkcd 1803"
# LAST	Dfr	"strip de xkcd n°1803"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1803rd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1803/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1803/"
# LAST	P433	"1803"	S854	"http://www.xkcd.com/1803/"
# LAST	P577	+00000002017-02-24T00:00:00Z/11	S854	"http://www.xkcd.com/1803/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1803/"
# LAST	P2699	"http://www.xkcd.com/1803/"	S854	"http://www.xkcd.com/1803/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1803/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1803/"
#
# CREATE
# LAST	Lfr	"Video Content"
# LAST	Afr	"xkcd 1804"
# LAST	Len	"Video Content"
# LAST	Aen	"xkcd 1804"
# LAST	Lbr	"Video Content"
# LAST	Abr	"xkcd 1804"
# LAST	Lde	"Video Content"
# LAST	Ade	"xkcd 1804"
# LAST	Dfr	"strip de xkcd n°1804"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1804th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1804/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1804/"
# LAST	P433	"1804"	S854	"http://www.xkcd.com/1804/"
# LAST	P577	+00000002017-02-27T00:00:00Z/11	S854	"http://www.xkcd.com/1804/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1804/"
# LAST	P2699	"http://www.xkcd.com/1804/"	S854	"http://www.xkcd.com/1804/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1804/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1804/"
#
# CREATE
# LAST	Lfr	"Unpublished Discoveries"
# LAST	Afr	"xkcd 1805"
# LAST	Len	"Unpublished Discoveries"
# LAST	Aen	"xkcd 1805"
# LAST	Lbr	"Unpublished Discoveries"
# LAST	Abr	"xkcd 1805"
# LAST	Lde	"Unpublished Discoveries"
# LAST	Ade	"xkcd 1805"
# LAST	Dfr	"strip de xkcd n°1805"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1805th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1805/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1805/"
# LAST	P433	"1805"	S854	"http://www.xkcd.com/1805/"
# LAST	P577	+00000002017-03-01T00:00:00Z/11	S854	"http://www.xkcd.com/1805/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1805/"
# LAST	P2699	"http://www.xkcd.com/1805/"	S854	"http://www.xkcd.com/1805/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1805/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1805/"
#
# CREATE
# LAST	Lfr	"Borrow Your Laptop"
# LAST	Afr	"xkcd 1806"
# LAST	Len	"Borrow Your Laptop"
# LAST	Aen	"xkcd 1806"
# LAST	Lbr	"Borrow Your Laptop"
# LAST	Abr	"xkcd 1806"
# LAST	Lde	"Borrow Your Laptop"
# LAST	Ade	"xkcd 1806"
# LAST	Dfr	"strip de xkcd n°1806"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1806th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1806/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1806/"
# LAST	P433	"1806"	S854	"http://www.xkcd.com/1806/"
# LAST	P577	+00000002017-03-03T00:00:00Z/11	S854	"http://www.xkcd.com/1806/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1806/"
# LAST	P2699	"http://www.xkcd.com/1806/"	S854	"http://www.xkcd.com/1806/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1806/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1806/"
#
# CREATE
# LAST	Lfr	"Listening"
# LAST	Afr	"xkcd 1807"
# LAST	Len	"Listening"
# LAST	Aen	"xkcd 1807"
# LAST	Lbr	"Listening"
# LAST	Abr	"xkcd 1807"
# LAST	Lde	"Listening"
# LAST	Ade	"xkcd 1807"
# LAST	Dfr	"strip de xkcd n°1807"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1807th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1807/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1807/"
# LAST	P433	"1807"	S854	"http://www.xkcd.com/1807/"
# LAST	P577	+00000002017-03-06T00:00:00Z/11	S854	"http://www.xkcd.com/1807/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1807/"
# LAST	P2699	"http://www.xkcd.com/1807/"	S854	"http://www.xkcd.com/1807/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1807/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1807/"
#
# CREATE
# LAST	Lfr	"Hacking"
# LAST	Afr	"xkcd 1808"
# LAST	Len	"Hacking"
# LAST	Aen	"xkcd 1808"
# LAST	Lbr	"Hacking"
# LAST	Abr	"xkcd 1808"
# LAST	Lde	"Hacking"
# LAST	Ade	"xkcd 1808"
# LAST	Dfr	"strip de xkcd n°1808"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1808th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1808/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1808/"
# LAST	P433	"1808"	S854	"http://www.xkcd.com/1808/"
# LAST	P577	+00000002017-03-08T00:00:00Z/11	S854	"http://www.xkcd.com/1808/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1808/"
# LAST	P2699	"http://www.xkcd.com/1808/"	S854	"http://www.xkcd.com/1808/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1808/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1808/"
#
# CREATE
# LAST	Lfr	"xkcd Phone 5"
# LAST	Afr	"xkcd 1809"
# LAST	Len	"xkcd Phone 5"
# LAST	Aen	"xkcd 1809"
# LAST	Lbr	"xkcd Phone 5"
# LAST	Abr	"xkcd 1809"
# LAST	Lde	"xkcd Phone 5"
# LAST	Ade	"xkcd 1809"
# LAST	Dfr	"strip de xkcd n°1809"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1809th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1809/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1809/"
# LAST	P433	"1809"	S854	"http://www.xkcd.com/1809/"
# LAST	P577	+00000002017-03-10T00:00:00Z/11	S854	"http://www.xkcd.com/1809/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1809/"
# LAST	P2699	"http://www.xkcd.com/1809/"	S854	"http://www.xkcd.com/1809/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1809/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1809/"
#
# CREATE
# LAST	Lfr	"Chat Systems"
# LAST	Afr	"xkcd 1810"
# LAST	Len	"Chat Systems"
# LAST	Aen	"xkcd 1810"
# LAST	Lbr	"Chat Systems"
# LAST	Abr	"xkcd 1810"
# LAST	Lde	"Chat Systems"
# LAST	Ade	"xkcd 1810"
# LAST	Dfr	"strip de xkcd n°1810"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1810th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1810/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1810/"
# LAST	P433	"1810"	S854	"http://www.xkcd.com/1810/"
# LAST	P577	+00000002017-03-13T00:00:00Z/11	S854	"http://www.xkcd.com/1810/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1810/"
# LAST	P2699	"http://www.xkcd.com/1810/"	S854	"http://www.xkcd.com/1810/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1810/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1810/"
#
# CREATE
# LAST	Lfr	"Best-Tasting Colors"
# LAST	Afr	"xkcd 1811"
# LAST	Len	"Best-Tasting Colors"
# LAST	Aen	"xkcd 1811"
# LAST	Lbr	"Best-Tasting Colors"
# LAST	Abr	"xkcd 1811"
# LAST	Lde	"Best-Tasting Colors"
# LAST	Ade	"xkcd 1811"
# LAST	Dfr	"strip de xkcd n°1811"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1811th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1811/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1811/"
# LAST	P433	"1811"	S854	"http://www.xkcd.com/1811/"
# LAST	P577	+00000002017-03-15T00:00:00Z/11	S854	"http://www.xkcd.com/1811/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1811/"
# LAST	P2699	"http://www.xkcd.com/1811/"	S854	"http://www.xkcd.com/1811/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1811/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1811/"
#
# CREATE
# LAST	Lfr	"Onboarding"
# LAST	Afr	"xkcd 1812"
# LAST	Len	"Onboarding"
# LAST	Aen	"xkcd 1812"
# LAST	Lbr	"Onboarding"
# LAST	Abr	"xkcd 1812"
# LAST	Lde	"Onboarding"
# LAST	Ade	"xkcd 1812"
# LAST	Dfr	"strip de xkcd n°1812"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1812th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1812/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1812/"
# LAST	P433	"1812"	S854	"http://www.xkcd.com/1812/"
# LAST	P577	+00000002017-03-17T00:00:00Z/11	S854	"http://www.xkcd.com/1812/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1812/"
# LAST	P2699	"http://www.xkcd.com/1812/"	S854	"http://www.xkcd.com/1812/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1812/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1812/"
#
# CREATE
# LAST	Lfr	"Vomiting Emoji"
# LAST	Afr	"xkcd 1813"
# LAST	Len	"Vomiting Emoji"
# LAST	Aen	"xkcd 1813"
# LAST	Lbr	"Vomiting Emoji"
# LAST	Abr	"xkcd 1813"
# LAST	Lde	"Vomiting Emoji"
# LAST	Ade	"xkcd 1813"
# LAST	Dfr	"strip de xkcd n°1813"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1813th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1813/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1813/"
# LAST	P433	"1813"	S854	"http://www.xkcd.com/1813/"
# LAST	P577	+00000002017-03-20T00:00:00Z/11	S854	"http://www.xkcd.com/1813/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1813/"
# LAST	P2699	"http://www.xkcd.com/1813/"	S854	"http://www.xkcd.com/1813/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1813/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1813/"
#
# CREATE
# LAST	Lfr	"Color Pattern"
# LAST	Afr	"xkcd 1814"
# LAST	Len	"Color Pattern"
# LAST	Aen	"xkcd 1814"
# LAST	Lbr	"Color Pattern"
# LAST	Abr	"xkcd 1814"
# LAST	Lde	"Color Pattern"
# LAST	Ade	"xkcd 1814"
# LAST	Dfr	"strip de xkcd n°1814"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1814th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1814/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1814/"
# LAST	P433	"1814"	S854	"http://www.xkcd.com/1814/"
# LAST	P577	+00000002017-03-22T00:00:00Z/11	S854	"http://www.xkcd.com/1814/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1814/"
# LAST	P2699	"http://www.xkcd.com/1814/"	S854	"http://www.xkcd.com/1814/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1814/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1814/"
#
# CREATE
# LAST	Lfr	"Flag"
# LAST	Afr	"xkcd 1815"
# LAST	Len	"Flag"
# LAST	Aen	"xkcd 1815"
# LAST	Lbr	"Flag"
# LAST	Abr	"xkcd 1815"
# LAST	Lde	"Flag"
# LAST	Ade	"xkcd 1815"
# LAST	Dfr	"strip de xkcd n°1815"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1815th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1815/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1815/"
# LAST	P433	"1815"	S854	"http://www.xkcd.com/1815/"
# LAST	P577	+00000002017-03-24T00:00:00Z/11	S854	"http://www.xkcd.com/1815/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1815/"
# LAST	P2699	"http://www.xkcd.com/1815/"	S854	"http://www.xkcd.com/1815/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1815/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1815/"
#
# CREATE
# LAST	Lfr	"Mispronunciation"
# LAST	Afr	"xkcd 1816"
# LAST	Len	"Mispronunciation"
# LAST	Aen	"xkcd 1816"
# LAST	Lbr	"Mispronunciation"
# LAST	Abr	"xkcd 1816"
# LAST	Lde	"Mispronunciation"
# LAST	Ade	"xkcd 1816"
# LAST	Dfr	"strip de xkcd n°1816"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1816th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1816/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1816/"
# LAST	P433	"1816"	S854	"http://www.xkcd.com/1816/"
# LAST	P577	+00000002017-03-27T00:00:00Z/11	S854	"http://www.xkcd.com/1816/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1816/"
# LAST	P2699	"http://www.xkcd.com/1816/"	S854	"http://www.xkcd.com/1816/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1816/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1816/"
#
# CREATE
# LAST	Lfr	"Incognito Mode"
# LAST	Afr	"xkcd 1817"
# LAST	Len	"Incognito Mode"
# LAST	Aen	"xkcd 1817"
# LAST	Lbr	"Incognito Mode"
# LAST	Abr	"xkcd 1817"
# LAST	Lde	"Incognito Mode"
# LAST	Ade	"xkcd 1817"
# LAST	Dfr	"strip de xkcd n°1817"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1817th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1817/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1817/"
# LAST	P433	"1817"	S854	"http://www.xkcd.com/1817/"
# LAST	P577	+00000002017-03-29T00:00:00Z/11	S854	"http://www.xkcd.com/1817/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1817/"
# LAST	P2699	"http://www.xkcd.com/1817/"	S854	"http://www.xkcd.com/1817/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1817/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1817/"
#
# CREATE
# LAST	Lfr	"Rayleigh Scattering"
# LAST	Afr	"xkcd 1818"
# LAST	Len	"Rayleigh Scattering"
# LAST	Aen	"xkcd 1818"
# LAST	Lbr	"Rayleigh Scattering"
# LAST	Abr	"xkcd 1818"
# LAST	Lde	"Rayleigh Scattering"
# LAST	Ade	"xkcd 1818"
# LAST	Dfr	"strip de xkcd n°1818"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1818th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1818/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1818/"
# LAST	P433	"1818"	S854	"http://www.xkcd.com/1818/"
# LAST	P577	+00000002017-03-31T00:00:00Z/11	S854	"http://www.xkcd.com/1818/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1818/"
# LAST	P2699	"http://www.xkcd.com/1818/"	S854	"http://www.xkcd.com/1818/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1818/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1818/"
#
# CREATE
# LAST	Lfr	"Sweet 16"
# LAST	Afr	"xkcd 1819"
# LAST	Len	"Sweet 16"
# LAST	Aen	"xkcd 1819"
# LAST	Lbr	"Sweet 16"
# LAST	Abr	"xkcd 1819"
# LAST	Lde	"Sweet 16"
# LAST	Ade	"xkcd 1819"
# LAST	Dfr	"strip de xkcd n°1819"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1819th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1819/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1819/"
# LAST	P433	"1819"	S854	"http://www.xkcd.com/1819/"
# LAST	P577	+00000002017-04-03T00:00:00Z/11	S854	"http://www.xkcd.com/1819/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1819/"
# LAST	P2699	"http://www.xkcd.com/1819/"	S854	"http://www.xkcd.com/1819/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1819/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1819/"
#
# CREATE
# LAST	Lfr	"Security Advice"
# LAST	Afr	"xkcd 1820"
# LAST	Len	"Security Advice"
# LAST	Aen	"xkcd 1820"
# LAST	Lbr	"Security Advice"
# LAST	Abr	"xkcd 1820"
# LAST	Lde	"Security Advice"
# LAST	Ade	"xkcd 1820"
# LAST	Dfr	"strip de xkcd n°1820"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1820th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1820/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1820/"
# LAST	P433	"1820"	S854	"http://www.xkcd.com/1820/"
# LAST	P577	+00000002017-04-05T00:00:00Z/11	S854	"http://www.xkcd.com/1820/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1820/"
# LAST	P2699	"http://www.xkcd.com/1820/"	S854	"http://www.xkcd.com/1820/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1820/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1820/"
#
# CREATE
# LAST	Lfr	"Incinerator"
# LAST	Afr	"xkcd 1821"
# LAST	Len	"Incinerator"
# LAST	Aen	"xkcd 1821"
# LAST	Lbr	"Incinerator"
# LAST	Abr	"xkcd 1821"
# LAST	Lde	"Incinerator"
# LAST	Ade	"xkcd 1821"
# LAST	Dfr	"strip de xkcd n°1821"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1821st strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1821/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1821/"
# LAST	P433	"1821"	S854	"http://www.xkcd.com/1821/"
# LAST	P577	+00000002017-04-07T00:00:00Z/11	S854	"http://www.xkcd.com/1821/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1821/"
# LAST	P2699	"http://www.xkcd.com/1821/"	S854	"http://www.xkcd.com/1821/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1821/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1821/"
#
# CREATE
# LAST	Lfr	"Existential Bug Reports"
# LAST	Afr	"xkcd 1822"
# LAST	Len	"Existential Bug Reports"
# LAST	Aen	"xkcd 1822"
# LAST	Lbr	"Existential Bug Reports"
# LAST	Abr	"xkcd 1822"
# LAST	Lde	"Existential Bug Reports"
# LAST	Ade	"xkcd 1822"
# LAST	Dfr	"strip de xkcd n°1822"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1822nd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1822/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1822/"
# LAST	P433	"1822"	S854	"http://www.xkcd.com/1822/"
# LAST	P577	+00000002017-04-10T00:00:00Z/11	S854	"http://www.xkcd.com/1822/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1822/"
# LAST	P2699	"http://www.xkcd.com/1822/"	S854	"http://www.xkcd.com/1822/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1822/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1822/"
#
# CREATE
# LAST	Lfr	"Hottest Editors"
# LAST	Afr	"xkcd 1823"
# LAST	Len	"Hottest Editors"
# LAST	Aen	"xkcd 1823"
# LAST	Lbr	"Hottest Editors"
# LAST	Abr	"xkcd 1823"
# LAST	Lde	"Hottest Editors"
# LAST	Ade	"xkcd 1823"
# LAST	Dfr	"strip de xkcd n°1823"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1823rd strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1823/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1823/"
# LAST	P433	"1823"	S854	"http://www.xkcd.com/1823/"
# LAST	P577	+00000002017-04-12T00:00:00Z/11	S854	"http://www.xkcd.com/1823/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1823/"
# LAST	P2699	"http://www.xkcd.com/1823/"	S854	"http://www.xkcd.com/1823/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1823/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1823/"
#
# CREATE
# LAST	Lfr	"Identification Chart"
# LAST	Afr	"xkcd 1824"
# LAST	Len	"Identification Chart"
# LAST	Aen	"xkcd 1824"
# LAST	Lbr	"Identification Chart"
# LAST	Abr	"xkcd 1824"
# LAST	Lde	"Identification Chart"
# LAST	Ade	"xkcd 1824"
# LAST	Dfr	"strip de xkcd n°1824"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1824th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1824/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1824/"
# LAST	P433	"1824"	S854	"http://www.xkcd.com/1824/"
# LAST	P577	+00000002017-04-14T00:00:00Z/11	S854	"http://www.xkcd.com/1824/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1824/"
# LAST	P2699	"http://www.xkcd.com/1824/"	S854	"http://www.xkcd.com/1824/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1824/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1824/"
#
# CREATE
# LAST	Lfr	"7 Eleven"
# LAST	Afr	"xkcd 1825"
# LAST	Len	"7 Eleven"
# LAST	Aen	"xkcd 1825"
# LAST	Lbr	"7 Eleven"
# LAST	Abr	"xkcd 1825"
# LAST	Lde	"7 Eleven"
# LAST	Ade	"xkcd 1825"
# LAST	Dfr	"strip de xkcd n°1825"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1825th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1825/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1825/"
# LAST	P433	"1825"	S854	"http://www.xkcd.com/1825/"
# LAST	P577	+00000002017-04-17T00:00:00Z/11	S854	"http://www.xkcd.com/1825/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1825/"
# LAST	P2699	"http://www.xkcd.com/1825/"	S854	"http://www.xkcd.com/1825/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1825/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1825/"
#
# CREATE
# LAST	Lfr	"Birdwatching"
# LAST	Afr	"xkcd 1826"
# LAST	Len	"Birdwatching"
# LAST	Aen	"xkcd 1826"
# LAST	Lbr	"Birdwatching"
# LAST	Abr	"xkcd 1826"
# LAST	Lde	"Birdwatching"
# LAST	Ade	"xkcd 1826"
# LAST	Dfr	"strip de xkcd n°1826"
# LAST	Dde	"Folge des Webcomics xkcd"
# LAST	Den	"1826th strip of the webcomic xkcd"
# LAST	P31	Q838795	S854	"http://www.xkcd.com/1826/"
# LAST	P361	Q13915	S854	"http://www.xkcd.com/1826/"
# LAST	P433	"1826"	S854	"http://www.xkcd.com/1826/"
# LAST	P577	+00000002017-04-19T00:00:00Z/11	S854	"http://www.xkcd.com/1826/"
# LAST	P50	Q285048	S854	"http://www.xkcd.com/1826/"
# LAST	P2699	"http://www.xkcd.com/1826/"	S854	"http://www.xkcd.com/1826/"
# LAST	P364	Q1860	S854	"http://www.xkcd.com/1826/"
# LAST	P275	Q6936496	S854	"http://www.xkcd.com/1826/"

# %% [markdown]
# Il ne reste plus qu'à copier-coller le résultat dans l'outil [QuickStatements](https://tools.wmflabs.org/quickstatements/#) ! Note : l'outil est en phase de refonte importante, l'interface est donc en travaux et sera améliorée.
#
# À la première connexion à l'outil, il faut donner l'autorisation à QuickStatements d'utiliser votre compte Wikidata, en cliquant sur le lien « Log in » en haut à droite.
#
# Ensuite, il faut cliquer sur le menu « Import Commands », puis « Version 1 format ». Cela ouvre un formulaire dans lequel on peut coller le résultat du script ci-dessus, puis cliquer sur Import. Les commandes interprétées s'affichent alors dans un tableau et il suffit de cliquer sur « Run » pour que les données soient finalement importées sur Wikidata.
#
# La documentation de Quick Statements est disponible sur l'ancienne version de l'outil : http://tools.wmflabs.org/wikidata-todo/quick_statements.php
