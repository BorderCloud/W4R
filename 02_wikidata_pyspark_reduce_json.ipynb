# %% [markdown]
# # Savoir sélectionner des données
#
# Nous allons voir comment lire le dump de Wikidata et y sélectionner des données pour fabriquer notre propre CSV.

# %% [markdown]
# ## Comment lire le Json du dump de Wikidata ?
#
# On retire les lignes vides ou qui ne contiennent pas d'enregistrement et la virgule à la fin.

# %%
import json
#import pyspark
#sc = pyspark.SparkContext('local[*]')

wikiFile = sc.textFile('wikidata-sample.json')

#remove the [ ] in the file and the last comma
rdd = wikiFile\
        .filter(lambda x: '{' in x)\
        .map(lambda x: json.loads(x[:-1]))\
        .take(1)

formatted = json.dumps(rdd, sort_keys=True, indent=4, separators=(',', ': '))
print(formatted)
# Out:
# [
#     {
#         "aliases": {
#             "ar": [
#                 {
#                     "language": "ar",
#                     "value": "\u0625\u0633\u0643\u062a\u0644\u0646\u062f\u0627"
#                 }
#             ],
#             "be-tarask": [
#                 {
#                     "language": "be-tarask",
#                     "value": "\u0428\u043a\u043e\u0446\u044b\u044f"
#                 }
#             ],
#             "ca": [
#                 {
#                     "language": "ca",
#                     "value": "Scotland"
#                 }
#             ],
#             "en": [
#                 {
#                     "language": "en",
#                     "value": "Alba"
#                 },
#                 {
#                     "language": "en",
#                     "value": "Scotland, United Kingdom"
#                 },
#                 {
#                     "language": "en",
#                     "value": "SCT"
#                 },
#                 {
#                     "language": "en",
#                     "value": "Caledonia"
#                 },
#                 {
#                     "language": "en",
#                     "value": "scot"
#                 }
#             ],
#             "en-gb": [
#                 {
#                     "language": "en-gb",
#                     "value": "Caledonia"
#                 }
#             ],
#             "eo": [
#                 {
#                     "language": "eo",
#                     "value": "Skotio"
#                 },
#                 {
#                     "language": "eo",
#                     "value": "Skotujo"
#                 }
#             ],
#             "hr": [
#                 {
#                     "language": "hr",
#                     "value": "Kaledonija"
#                 }
#             ],
#             "kn": [
#                 {
#                     "language": "kn",
#                     "value": "\u0c86\u0cb2\u0ccd\u0cac\u0cbe"
#                 }
#             ],
#             "ta": [
#                 {
#                     "language": "ta",
#                     "value": "\u0b86\u0bb2\u0bcd\u0baa\u0bbe"
#                 }
#             ],
#             "th": [
#                 {
#                     "language": "th",
#                     "value": "\u0e41\u0e04\u0e27\u0e49\u0e19\u0e2a\u0e01\u0e47\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c"
#                 },
#                 {
#                     "language": "th",
#                     "value": "\u0e2a\u0e01\u0e47\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c"
#                 },
#                 {
#                     "language": "th",
#                     "value": "\u0e2a\u0e01\u0e4a\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c"
#                 },
#                 {
#                     "language": "th",
#                     "value": "Scotland"
#                 },
#                 {
#                     "language": "th",
#                     "value": "\u0e41\u0e04\u0e27\u0e49\u0e19\u0e2a\u0e01\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c"
#                 },
#                 {
#                     "language": "th",
#                     "value": "\u0e2a\u0e01\u0e47\u0e2d\u0e15"
#                 },
#                 {
#                     "language": "th",
#                     "value": "\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e2a\u0e01\u0e47\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c"
#                 },
#                 {
#                     "language": "th",
#                     "value": "\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e2a\u0e01\u0e4a\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c"
#                 }
#             ]
#         },
#         "claims": {
#             "P1036": [
#                 {
#                     "id": "Q22$7b6061b8-4311-099d-3d2f-3a7de56cf23a",
#                     "mainsnak": {
#                         "datatype": "string",
#                         "datavalue": {
#                             "type": "string",
#                             "value": "2--411"
#                         },
#                         "property": "P1036",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1151": [
#                 {
#                     "id": "Q22$04c44166-4108-c316-d451-aa9a60524349",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q8143311",
#                                 "numeric-id": 8143311
#                             }
#                         },
#                         "property": "P1151",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1245": [
#                 {
#                     "id": "Q22$1230f800-4cb0-aff4-6564-dd7f075411bb",
#                     "mainsnak": {
#                         "datatype": "external-id",
#                         "datavalue": {
#                             "type": "string",
#                             "value": "374042"
#                         },
#                         "property": "P1245",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P131": [
#                 {
#                     "id": "Q22$2D126F27-49E2-48E1-ABF5-E9E4B412DE0B",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q145",
#                                 "numeric-id": 145
#                             }
#                         },
#                         "property": "P131",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P580": [
#                             {
#                                 "datatype": "time",
#                                 "datavalue": {
#                                     "type": "time",
#                                     "value": {
#                                         "after": 0,
#                                         "before": 0,
#                                         "calendarmodel": "http://www.wikidata.org/entity/Q1985727",
#                                         "precision": 11,
#                                         "time": "+1922-12-06T00:00:00Z",
#                                         "timezone": 0
#                                     }
#                                 },
#                                 "hash": "c24890c9f7e85c4cf68134fd4c53102e6029d197",
#                                 "property": "P580",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P580"
#                     ],
#                     "rank": "preferred",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$A6846254-E781-4690-9F53-CCB1839973C1",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q174193",
#                                 "numeric-id": 174193
#                             }
#                         },
#                         "property": "P131",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P580": [
#                             {
#                                 "datatype": "time",
#                                 "datavalue": {
#                                     "type": "time",
#                                     "value": {
#                                         "after": 0,
#                                         "before": 0,
#                                         "calendarmodel": "http://www.wikidata.org/entity/Q1985727",
#                                         "precision": 11,
#                                         "time": "+1800-12-31T00:00:00Z",
#                                         "timezone": 0
#                                     }
#                                 },
#                                 "hash": "b47c060abd5a33ed930ed4807fd92cde5ab438c7",
#                                 "property": "P580",
#                                 "snaktype": "value"
#                             }
#                         ],
#                         "P582": [
#                             {
#                                 "datatype": "time",
#                                 "datavalue": {
#                                     "type": "time",
#                                     "value": {
#                                         "after": 0,
#                                         "before": 0,
#                                         "calendarmodel": "http://www.wikidata.org/entity/Q1985727",
#                                         "precision": 11,
#                                         "time": "+1922-12-06T00:00:00Z",
#                                         "timezone": 0
#                                     }
#                                 },
#                                 "hash": "88c49a979a2f005d7c631e071789b0b3ea233bd3",
#                                 "property": "P582",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P580",
#                         "P582"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$706bae70-404a-4c32-0dfb-b8d0d06fbc8a",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q161885",
#                                 "numeric-id": 161885
#                             }
#                         },
#                         "property": "P131",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P580": [
#                             {
#                                 "datatype": "time",
#                                 "datavalue": {
#                                     "type": "time",
#                                     "value": {
#                                         "after": 0,
#                                         "before": 0,
#                                         "calendarmodel": "http://www.wikidata.org/entity/Q1985727",
#                                         "precision": 11,
#                                         "time": "+1707-01-01T00:00:00Z",
#                                         "timezone": 0
#                                     }
#                                 },
#                                 "hash": "51195d4d505e7d8bc1b29d4b54aa783cae09c62b",
#                                 "property": "P580",
#                                 "snaktype": "value"
#                             }
#                         ],
#                         "P582": [
#                             {
#                                 "datatype": "time",
#                                 "datavalue": {
#                                     "type": "time",
#                                     "value": {
#                                         "after": 0,
#                                         "before": 0,
#                                         "calendarmodel": "http://www.wikidata.org/entity/Q1985727",
#                                         "precision": 11,
#                                         "time": "+1800-12-31T00:00:00Z",
#                                         "timezone": 0
#                                     }
#                                 },
#                                 "hash": "863c4fac7708f12f0e84df41ac883b415ce0bf18",
#                                 "property": "P582",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P580",
#                         "P582"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1365": [
#                 {
#                     "id": "Q22$745eeda7-47fc-8a9e-9657-1435027b16d5",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q230791",
#                                 "numeric-id": 230791
#                             }
#                         },
#                         "property": "P1365",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1417": [
#                 {
#                     "id": "Q22$145523FE-9C4D-479E-B691-DBEB2192005D",
#                     "mainsnak": {
#                         "datatype": "external-id",
#                         "datavalue": {
#                             "type": "string",
#                             "value": "place/Scotland"
#                         },
#                         "property": "P1417",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1464": [
#                 {
#                     "id": "Q22$6EFD869C-8648-4501-9B5B-4552E3CCF983",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q8079733",
#                                 "numeric-id": 8079733
#                             }
#                         },
#                         "property": "P1464",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "references": [
#                         {
#                             "hash": "288ab581e7d2d02995a26dfa8b091d96e78457fc",
#                             "snaks": {
#                                 "P143": [
#                                     {
#                                         "datatype": "wikibase-item",
#                                         "datavalue": {
#                                             "type": "wikibase-entityid",
#                                             "value": {
#                                                 "entity-type": "item",
#                                                 "id": "Q206855",
#                                                 "numeric-id": 206855
#                                             }
#                                         },
#                                         "property": "P143",
#                                         "snaktype": "value"
#                                     }
#                                 ]
#                             },
#                             "snaks-order": [
#                                 "P143"
#                             ]
#                         }
#                     ],
#                     "type": "statement"
#                 }
#             ],
#             "P1465": [
#                 {
#                     "id": "Q22$EA1EE3C4-4EEA-496C-8A2C-C5C6ED4B21EC",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q8365629",
#                                 "numeric-id": 8365629
#                             }
#                         },
#                         "property": "P1465",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "references": [
#                         {
#                             "hash": "288ab581e7d2d02995a26dfa8b091d96e78457fc",
#                             "snaks": {
#                                 "P143": [
#                                     {
#                                         "datatype": "wikibase-item",
#                                         "datavalue": {
#                                             "type": "wikibase-entityid",
#                                             "value": {
#                                                 "entity-type": "item",
#                                                 "id": "Q206855",
#                                                 "numeric-id": 206855
#                                             }
#                                         },
#                                         "property": "P143",
#                                         "snaktype": "value"
#                                     }
#                                 ]
#                             },
#                             "snaks-order": [
#                                 "P143"
#                             ]
#                         }
#                     ],
#                     "type": "statement"
#                 }
#             ],
#             "P150": [
#                 {
#                     "id": "Q22$9B74621A-901C-4BC6-9589-46399A581A64",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q100166",
#                                 "numeric-id": 100166
#                             }
#                         },
#                         "property": "P150",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1546": [
#                 {
#                     "id": "Q22$811a36c6-4cf0-e32a-f2a2-1cb82d5f9201",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q2016568",
#                                 "numeric-id": 2016568
#                             }
#                         },
#                         "property": "P1546",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1549": [
#                 {
#                     "id": "Q22$540b079c-43d8-e0ca-43b2-431f1a9f41f6",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "en",
#                                 "text": "Scottish"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$07dd176b-4efa-9af4-2d9e-4e2d6129fe67",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "de",
#                                 "text": "schottisch"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$f45ecb5e-46a6-b7e5-7c8f-a329c39fe3af",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "de",
#                                 "text": "Schotte"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q499327",
#                                         "numeric-id": 499327
#                                     }
#                                 },
#                                 "hash": "735874569aa9bd9762a6bf8dea8d3b3faae7d12b",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$09fdcd8d-479c-3189-f3a5-5505b2a5d0cc",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "de",
#                                 "text": "Schottin"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q1775415",
#                                         "numeric-id": 1775415
#                                     }
#                                 },
#                                 "hash": "c6a3b7c3120e0b93b2f67b2d7081beed1709d4d6",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$8868b176-41db-2879-ed24-e1ec508a0948",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "nl",
#                                 "text": "Schot"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$7bb3201d-4dc7-3af9-a9a7-9ffb8e860d97",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "fr",
#                                 "text": "\u00c9cossais"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q6581097",
#                                         "numeric-id": 6581097
#                                     }
#                                 },
#                                 "hash": "9cc07521551419c9220b15f5deb65bfdb0308dff",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$c297fb86-4ed1-cf3a-2827-23c547b28453",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "fr",
#                                 "text": "\u00c9cossaise"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q6581072",
#                                         "numeric-id": 6581072
#                                     }
#                                 },
#                                 "hash": "7e6de72848cf4c352251550e1f387eb07c76b893",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$6ad11fb0-42db-5bc5-186e-94d3a17107db",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "hu",
#                                 "text": "sk\u00f3t"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$a4536c75-4b34-e78a-fadc-fc48049e3d36",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "el",
#                                 "text": "\u03c3\u03ba\u03c9\u03c4\u03c3\u03ad\u03b6\u03bf\u03c2"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q6581097",
#                                         "numeric-id": 6581097
#                                     }
#                                 },
#                                 "hash": "9cc07521551419c9220b15f5deb65bfdb0308dff",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$4362a929-4ac4-9901-c597-a24de34b0146",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "el",
#                                 "text": "\u03c3\u03ba\u03c9\u03c4\u03c3\u03ad\u03b6\u03b1"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$f96f94a0-4d1f-8b64-6eb9-4df808b0084e",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "bg",
#                                 "text": "\u0448\u043e\u0442\u043b\u0430\u043d\u0434\u0446\u0438"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q146786",
#                                         "numeric-id": 146786
#                                     }
#                                 },
#                                 "hash": "54d3caf1789c5ac2c20cd261a01935ccfa951387",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$0059bfc7-4e69-7380-af10-c8c7b0b85e91",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "bg",
#                                 "text": "\u0448\u043e\u0442\u043b\u0430\u043d\u0434\u0435\u0446"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q499327",
#                                         "numeric-id": 499327
#                                     }
#                                 },
#                                 "hash": "735874569aa9bd9762a6bf8dea8d3b3faae7d12b",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$627d00cc-4811-c939-f118-9f036590e47c",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "bg",
#                                 "text": "\u0448\u043e\u0442\u043b\u0430\u043d\u0434\u043a\u0430"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q1775415",
#                                         "numeric-id": 1775415
#                                     }
#                                 },
#                                 "hash": "c6a3b7c3120e0b93b2f67b2d7081beed1709d4d6",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$8d316350-4fa1-cc5f-4e21-17827dbb9b5b",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "he",
#                                 "text": "\u05e1\u05e7\u05d5\u05d8\u05d9\u05ea"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q6581072",
#                                         "numeric-id": 6581072
#                                     }
#                                 },
#                                 "hash": "7e6de72848cf4c352251550e1f387eb07c76b893",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$269d5658-44d2-fdbb-8789-471bfcd04300",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "he",
#                                 "text": "\u05e1\u05e7\u05d5\u05d8\u05d9"
#                             }
#                         },
#                         "property": "P1549",
#                         "snaktype": "value"
#                     },
#                     "qualifiers": {
#                         "P518": [
#                             {
#                                 "datatype": "wikibase-item",
#                                 "datavalue": {
#                                     "type": "wikibase-entityid",
#                                     "value": {
#                                         "entity-type": "item",
#                                         "id": "Q6581097",
#                                         "numeric-id": 6581097
#                                     }
#                                 },
#                                 "hash": "9cc07521551419c9220b15f5deb65bfdb0308dff",
#                                 "property": "P518",
#                                 "snaktype": "value"
#                             }
#                         ]
#                     },
#                     "qualifiers-order": [
#                         "P518"
#                     ],
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1566": [
#                 {
#                     "id": "Q22$B1B9EA32-0EFD-40A6-96C6-FE6BA3021EF2",
#                     "mainsnak": {
#                         "datatype": "external-id",
#                         "datavalue": {
#                             "type": "string",
#                             "value": "2638360"
#                         },
#                         "property": "P1566",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "references": [
#                         {
#                             "hash": "64133510dcdf15e7943de41e4835c673fc5d6fe4",
#                             "snaks": {
#                                 "P143": [
#                                     {
#                                         "datatype": "wikibase-item",
#                                         "datavalue": {
#                                             "type": "wikibase-entityid",
#                                             "value": {
#                                                 "entity-type": "item",
#                                                 "id": "Q830106",
#                                                 "numeric-id": 830106
#                                             }
#                                         },
#                                         "property": "P143",
#                                         "snaktype": "value"
#                                     }
#                                 ]
#                             },
#                             "snaks-order": [
#                                 "P143"
#                             ]
#                         }
#                     ],
#                     "type": "statement"
#                 }
#             ],
#             "P159": [
#                 {
#                     "id": "Q22$3ccd9e56-45a5-6714-8d66-e9fd8bf2be1a",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q2379199",
#                                 "numeric-id": 2379199
#                             }
#                         },
#                         "property": "P159",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P163": [
#                 {
#                     "id": "q22$1117feb8-44e3-1284-7f65-8189afacf4c9",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q102392",
#                                 "numeric-id": 102392
#                             }
#                         },
#                         "property": "P163",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P17": [
#                 {
#                     "id": "q22$91B568B9-887D-4CD7-9534-AD889A997974",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q145",
#                                 "numeric-id": 145
#                             }
#                         },
#                         "property": "P17",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1705": [
#                 {
#                     "id": "Q22$80e95f7c-4207-5412-2a7b-e55bef6785a0",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "en",
#                                 "text": "Scotland"
#                             }
#                         },
#                         "property": "P1705",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 },
#                 {
#                     "id": "Q22$0a77d64f-4913-8b7c-5d62-ec6ecf4cbffe",
#                     "mainsnak": {
#                         "datatype": "monolingualtext",
#                         "datavalue": {
#                             "type": "monolingualtext",
#                             "value": {
#                                 "language": "gd",
#                                 "text": "Alba"
#                             }
#                         },
#                         "property": "P1705",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1711": [
#                 {
#                     "id": "Q22$8022FBAC-5FB2-4609-86B7-E93D01DC6D92",
#                     "mainsnak": {
#                         "datatype": "external-id",
#                         "datavalue": {
#                             "type": "string",
#                             "value": "114921"
#                         },
#                         "property": "P1711",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1740": [
#                 {
#                     "id": "Q22$20784E2D-5910-45B6-9A0A-0839522C66E2",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q6427237",
#                                 "numeric-id": 6427237
#                             }
#                         },
#                         "property": "P1740",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "type": "statement"
#                 }
#             ],
#             "P1792": [
#                 {
#                     "id": "Q22$01DA3438-8BD8-439C-822A-1424A7ED43F8",
#                     "mainsnak": {
#                         "datatype": "wikibase-item",
#                         "datavalue": {
#                             "type": "wikibase-entityid",
#                             "value": {
#                                 "entity-type": "item",
#                                 "id": "Q7030374",
#                                 "numeric-id": 7030374
#                             }
#                         },
#                         "property": "P1792",
#                         "snaktype": "value"
#                     },
#                     "rank": "normal",
#                     "references": [
#                         {
#                             "hash": "288ab581e7d2d02995a26dfa8b091d96e78457fc",
#                             "snaks": {
#                                 "P143": [
#                                     {
#                                         "datatype": "wikibase-item",
#                                         "datavalue": {
#                                             "type": "wikibase-entityid",
#                                             "value": {
#                                                 "entity-type": "item",
#                                                 "id": "Q206855",
#                                                 "numeric-id": 206855
#                                             }
# ...
#             },
#             "mkwiki": {
#                 "badges": [],
#                 "site": "mkwiki",
#                 "title": "\u0428\u043a\u043e\u0442\u0441\u043a\u0430"
#             },
#             "mlwiki": {
#                 "badges": [],
#                 "site": "mlwiki",
#                 "title": "\u0d38\u0d4d\u0d15\u0d4b\u0d1f\u0d4d\u0d1f\u0d4d\u200c\u0d32\u0d7b\u0d21\u0d4d"
#             },
#             "mnwiki": {
#                 "badges": [],
#                 "site": "mnwiki",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434"
#             },
#             "mrwiki": {
#                 "badges": [],
#                 "site": "mrwiki",
#                 "title": "\u0938\u094d\u0915\u0949\u091f\u0932\u0902\u0921"
#             },
#             "mswiki": {
#                 "badges": [],
#                 "site": "mswiki",
#                 "title": "Scotland"
#             },
#             "mtwiki": {
#                 "badges": [],
#                 "site": "mtwiki",
#                 "title": "Skozja"
#             },
#             "mywiki": {
#                 "badges": [],
#                 "site": "mywiki",
#                 "title": "\u1005\u1000\u1031\u102c\u1037\u1010\u101c\u1014\u103a\u1014\u102d\u102f\u1004\u103a\u1004\u1036"
#             },
#             "mznwiki": {
#                 "badges": [],
#                 "site": "mznwiki",
#                 "title": "\u0627\u0633\u06a9\u0627\u062a\u0644\u0646\u062f"
#             },
#             "nds_nlwiki": {
#                 "badges": [],
#                 "site": "nds_nlwiki",
#                 "title": "Schotlaand"
#             },
#             "ndswiki": {
#                 "badges": [],
#                 "site": "ndswiki",
#                 "title": "Schottland"
#             },
#             "newiki": {
#                 "badges": [],
#                 "site": "newiki",
#                 "title": "\u0938\u094d\u0915\u091f\u0932\u094d\u092f\u093e\u0928\u094d\u0921"
#             },
#             "nlwiki": {
#                 "badges": [],
#                 "site": "nlwiki",
#                 "title": "Schotland"
#             },
#             "nlwikivoyage": {
#                 "badges": [],
#                 "site": "nlwikivoyage",
#                 "title": "Schotland"
#             },
#             "nnwiki": {
#                 "badges": [],
#                 "site": "nnwiki",
#                 "title": "Skottland"
#             },
#             "novwiki": {
#                 "badges": [],
#                 "site": "novwiki",
#                 "title": "Skotia"
#             },
#             "nowiki": {
#                 "badges": [
#                     "Q17437798"
#                 ],
#                 "site": "nowiki",
#                 "title": "Skottland"
#             },
#             "nowikinews": {
#                 "badges": [],
#                 "site": "nowikinews",
#                 "title": "Kategori:Skottland"
#             },
#             "nrmwiki": {
#                 "badges": [],
#                 "site": "nrmwiki",
#                 "title": "\u00cacosse"
#             },
#             "ocwiki": {
#                 "badges": [],
#                 "site": "ocwiki",
#                 "title": "Esc\u00f2cia"
#             },
#             "oswiki": {
#                 "badges": [],
#                 "site": "oswiki",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438"
#             },
#             "pamwiki": {
#                 "badges": [],
#                 "site": "pamwiki",
#                 "title": "Scotland"
#             },
#             "papwiki": {
#                 "badges": [],
#                 "site": "papwiki",
#                 "title": "Eskosia"
#             },
#             "pawiki": {
#                 "badges": [],
#                 "site": "pawiki",
#                 "title": "\u0a38\u0a15\u0a3e\u0a1f\u0a32\u0a48\u0a02\u0a21"
#             },
#             "pcdwiki": {
#                 "badges": [],
#                 "site": "pcdwiki",
#                 "title": "\u00c9cosse"
#             },
#             "pihwiki": {
#                 "badges": [],
#                 "site": "pihwiki",
#                 "title": "Skotlund"
#             },
#             "plwiki": {
#                 "badges": [],
#                 "site": "plwiki",
#                 "title": "Szkocja"
#             },
#             "plwikinews": {
#                 "badges": [],
#                 "site": "plwikinews",
#                 "title": "Kategoria:Szkocja"
#             },
#             "plwikivoyage": {
#                 "badges": [],
#                 "site": "plwikivoyage",
#                 "title": "Szkocja"
#             },
#             "pmswiki": {
#                 "badges": [],
#                 "site": "pmswiki",
#                 "title": "Sc\u00f2ssia"
#             },
#             "pnbwiki": {
#                 "badges": [],
#                 "site": "pnbwiki",
#                 "title": "\u0633\u06a9\u0627\u0679\u0644\u06cc\u0646\u0688"
#             },
#             "ptwiki": {
#                 "badges": [],
#                 "site": "ptwiki",
#                 "title": "Esc\u00f3cia"
#             },
#             "ptwikinews": {
#                 "badges": [],
#                 "site": "ptwikinews",
#                 "title": "Categoria:Esc\u00f3cia"
#             },
#             "ptwikivoyage": {
#                 "badges": [],
#                 "site": "ptwikivoyage",
#                 "title": "Esc\u00f3cia"
#             },
#             "quwiki": {
#                 "badges": [],
#                 "site": "quwiki",
#                 "title": "Iskusya"
#             },
#             "rmwiki": {
#                 "badges": [],
#                 "site": "rmwiki",
#                 "title": "Scozia"
#             },
#             "roa_rupwiki": {
#                 "badges": [],
#                 "site": "roa_rupwiki",
#                 "title": "Scotlandia"
#             },
#             "rowiki": {
#                 "badges": [],
#                 "site": "rowiki",
#                 "title": "Sco\u021bia"
#             },
#             "ruwiki": {
#                 "badges": [],
#                 "site": "ruwiki",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f"
#             },
#             "ruwikinews": {
#                 "badges": [],
#                 "site": "ruwikinews",
#                 "title": "\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u044f:\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f"
#             },
#             "ruwikivoyage": {
#                 "badges": [],
#                 "site": "ruwikivoyage",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f"
#             },
#             "scnwiki": {
#                 "badges": [],
#                 "site": "scnwiki",
#                 "title": "Scozzia"
#             },
#             "scowiki": {
#                 "badges": [],
#                 "site": "scowiki",
#                 "title": "Scotland"
#             },
#             "scwiki": {
#                 "badges": [],
#                 "site": "scwiki",
#                 "title": "Iscotzia"
#             },
#             "shwiki": {
#                 "badges": [],
#                 "site": "shwiki",
#                 "title": "\u0160kotska"
#             },
#             "simplewiki": {
#                 "badges": [],
#                 "site": "simplewiki",
#                 "title": "Scotland"
#             },
#             "siwiki": {
#                 "badges": [],
#                 "site": "siwiki",
#                 "title": "\u0dc3\u0dca\u0d9a\u0ddc\u0da7\u0dca\u0dbd\u0db1\u0dca\u0dad\u0dba"
#             },
#             "skwiki": {
#                 "badges": [],
#                 "site": "skwiki",
#                 "title": "\u0160k\u00f3tsko"
#             },
#             "slwiki": {
#                 "badges": [],
#                 "site": "slwiki",
#                 "title": "\u0160kotska"
#             },
#             "smwiki": {
#                 "badges": [],
#                 "site": "smwiki",
#                 "title": "Sikotilani"
#             },
#             "snwiki": {
#                 "badges": [],
#                 "site": "snwiki",
#                 "title": "Scotland"
#             },
#             "sowiki": {
#                 "badges": [],
#                 "site": "sowiki",
#                 "title": "Skotland"
#             },
#             "sqwiki": {
#                 "badges": [
#                     "Q17437796"
#                 ],
#                 "site": "sqwiki",
#                 "title": "Skocia"
#             },
#             "sqwikinews": {
#                 "badges": [],
#                 "site": "sqwikinews",
#                 "title": "Kategoria:Skoci"
#             },
#             "srwiki": {
#                 "badges": [],
#                 "site": "srwiki",
#                 "title": "\u0428\u043a\u043e\u0442\u0441\u043a\u0430"
#             },
#             "srwikinews": {
#                 "badges": [],
#                 "site": "srwikinews",
#                 "title": "\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u0458\u0430:\u0428\u043a\u043e\u0442\u0441\u043a\u0430"
#             },
#             "sswiki": {
#                 "badges": [],
#                 "site": "sswiki",
#                 "title": "Sikoshilandi"
#             },
#             "stqwiki": {
#                 "badges": [],
#                 "site": "stqwiki",
#                 "title": "Skotlound"
#             },
#             "suwiki": {
#                 "badges": [],
#                 "site": "suwiki",
#                 "title": "Skotlandia"
#             },
#             "svwiki": {
#                 "badges": [],
#                 "site": "svwiki",
#                 "title": "Skottland"
#             },
#             "svwikinews": {
#                 "badges": [],
#                 "site": "svwikinews",
#                 "title": "Kategori:Skottland"
#             },
#             "svwikivoyage": {
#                 "badges": [],
#                 "site": "svwikivoyage",
#                 "title": "Skottland"
#             },
#             "swwiki": {
#                 "badges": [],
#                 "site": "swwiki",
#                 "title": "Uskoti"
#             },
#             "szlwiki": {
#                 "badges": [],
#                 "site": "szlwiki",
#                 "title": "Szkocyjo"
#             },
#             "tawiki": {
#                 "badges": [],
#                 "site": "tawiki",
#                 "title": "\u0b87\u0b9a\u0bc1\u0b95\u0bcd\u0b95\u0bca\u0b9f\u0bcd\u0bb2\u0bbe\u0ba8\u0bcd\u0ba4\u0bc1"
#             },
#             "tetwiki": {
#                 "badges": [],
#                 "site": "tetwiki",
#                 "title": "Esk\u00f3sia"
#             },
#             "tewiki": {
#                 "badges": [],
#                 "site": "tewiki",
#                 "title": "\u0c38\u0c4d\u0c15\u0c3e\u0c1f\u0c4d\u0c32\u0c3e\u0c02\u0c21\u0c4d"
#             },
#             "tgwiki": {
#                 "badges": [],
#                 "site": "tgwiki",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f"
#             },
#             "thwiki": {
#                 "badges": [],
#                 "site": "thwiki",
#                 "title": "\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e2a\u0e01\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c"
#             },
#             "tlwiki": {
#                 "badges": [],
#                 "site": "tlwiki",
#                 "title": "Scotland"
#             },
#             "tpiwiki": {
#                 "badges": [],
#                 "site": "tpiwiki",
#                 "title": "Skotlan"
#             },
#             "trwiki": {
#                 "badges": [],
#                 "site": "trwiki",
#                 "title": "\u0130sko\u00e7ya"
#             },
#             "trwikinews": {
#                 "badges": [],
#                 "site": "trwikinews",
#                 "title": "Kategori:\u0130sko\u00e7ya"
#             },
#             "ttwiki": {
#                 "badges": [
#                     "Q17437798"
#                 ],
#                 "site": "ttwiki",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f"
#             },
#             "ugwiki": {
#                 "badges": [],
#                 "site": "ugwiki",
#                 "title": "Shotlandiye"
#             },
#             "ukwiki": {
#                 "badges": [],
#                 "site": "ukwiki",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0456\u044f"
#             },
#             "ukwikivoyage": {
#                 "badges": [],
#                 "site": "ukwikivoyage",
#                 "title": "\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0456\u044f"
#             },
#             "urwiki": {
#                 "badges": [],
#                 "site": "urwiki",
#                 "title": "\u0633\u06a9\u0627\u0679 \u0644\u06cc\u0646\u0688"
#             },
#             "uzwiki": {
#                 "badges": [],
#                 "site": "uzwiki",
#                 "title": "Shotlandiya"
#             },
#             "vecwiki": {
#                 "badges": [],
#                 "site": "vecwiki",
#                 "title": "Scozia"
#             },
#             "vepwiki": {
#                 "badges": [],
#                 "site": "vepwiki",
#                 "title": "\u0160otlandii"
#             },
#             "viwiki": {
#                 "badges": [],
#                 "site": "viwiki",
#                 "title": "Scotland"
#             },
#             "viwikivoyage": {
#                 "badges": [],
#                 "site": "viwikivoyage",
#                 "title": "Scotland"
#             },
#             "vlswiki": {
#                 "badges": [],
#                 "site": "vlswiki",
#                 "title": "Schotland"
#             },
#             "vowiki": {
#                 "badges": [],
#                 "site": "vowiki",
#                 "title": "Skot\u00e4n"
#             },
#             "warwiki": {
#                 "badges": [],
#                 "site": "warwiki",
#                 "title": "Escocia"
#             },
#             "wawiki": {
#                 "badges": [],
#                 "site": "wawiki",
#                 "title": "Esc\u00f4sse"
#             },
#             "wuuwiki": {
#                 "badges": [],
#                 "site": "wuuwiki",
#                 "title": "\u82cf\u683c\u5170"
#             },
#             "xalwiki": {
#                 "badges": [],
#                 "site": "xalwiki",
#                 "title": "\u0421\u043a\u043e\u0442\u0438\u0448\u0438\u043d \u0422\u0430\u04a3\u04bb\u0447"
#             },
#             "xmfwiki": {
#                 "badges": [],
#                 "site": "xmfwiki",
#                 "title": "\u10e8\u10dd\u10e2\u10da\u10d0\u10dc\u10d3\u10d8\u10d0"
#             },
#             "yiwiki": {
#                 "badges": [],
#                 "site": "yiwiki",
#                 "title": "\u05e1\u05e7\u05d0\u05d8\u05dc\u05d0\u05e0\u05d3"
#             },
#             "yowiki": {
#                 "badges": [],
#                 "site": "yowiki",
#                 "title": "Sk\u1ecd\u0301tl\u00e1nd\u00ec"
#             },
#             "zeawiki": {
#                 "badges": [],
#                 "site": "zeawiki",
#                 "title": "Schotland"
#             },
#             "zh_classicalwiki": {
#                 "badges": [],
#                 "site": "zh_classicalwiki",
#                 "title": "\u8607\u683c\u862d"
#             },
#             "zh_min_nanwiki": {
#                 "badges": [],
#                 "site": "zh_min_nanwiki",
#                 "title": "So\u0358-kek-l\u00e2n"
#             },
#             "zh_yuewiki": {
#                 "badges": [],
#                 "site": "zh_yuewiki",
#                 "title": "\u8607\u683c\u862d"
#             },
#             "zhwiki": {
#                 "badges": [],
#                 "site": "zhwiki",
#                 "title": "\u8607\u683c\u862d"
#             },
#             "zhwikinews": {
#                 "badges": [],
#                 "site": "zhwikinews",
#                 "title": "Category:\u8607\u683c\u862d"
#             },
#             "zhwikivoyage": {
#                 "badges": [],
#                 "site": "zhwikivoyage",
#                 "title": "\u82cf\u683c\u5170"
#             },
#             "zuwiki": {
#                 "badges": [],
#                 "site": "zuwiki",
#                 "title": "IsiKotilandi"
#             }
#         },
#         "type": "item"
#     }
# ]

# %% [markdown]
# Avec avoir charger le Json, on peut ensuite intérroger les champs.

# %%
import json

wikiFile = sc.textFile('wikidata-sample.json')

extractWikidata = wikiFile \
  .filter(lambda x: '{' in x) \
  .map(lambda x: json.loads(x[:-1])) \
  .map(lambda x: x.get('id')) \
  .take(10)

print(extractWikidata)
# Out:
# ['Q22', 'Q31', 'Q1', 'Q13', 'Q23', 'Q35', 'Q44', 'Q64', 'Q82', 'Q84']

# %% [markdown]
# ## Comment créer un RDD (Resilient Distributed Dataset) de type KV (Key Value) ?
#
# Il est possible de fabriquer directement des DataFrame pour ensuite faire des requêtes SQL mais il est plus intéressant de sélectionner uniquement les données au travers de RDD pour permettre l'utilisation de cluster par la suite.
#
# Il nous faut commencer par générer la clé de nos pairs qui doit être un entier pour permettre d'utiliser la fonction join.

# %%
idWikidata = "Q4645654"
print(idWikidata)
print(type(idWikidata))

keyString = idWikidata[1:]
print(keyString)
print(type(keyString))

key = int(idWikidata[1:])
print(key)
print(type(key))
# Out:
# Q4645654
# <class 'str'>
# 4645654
# <class 'str'>
# 4645654
# <class 'int'>

# %% [markdown]
# On peut maintenant générer des RDD KV. Exemple :

# %%
import json

wikiFile = sc.textFile('wikidata-sample.json')

rddKV = wikiFile \
  .filter(lambda x: '{' in x) \
  .map(lambda x: json.loads(x[:-1])) \
  .map(lambda x: (
                  #Calculate the Key
                   int(x.get('id')[1:]),
                  #Select Value
                  x
                  )
      )\
  .take(1)

print(rddKV)
# Out:
# [(22, {'type': 'item', 'id': 'Q22', 'labels': {'en-gb': {'language': 'en-gb', 'value': 'Scotland'}, 'en': {'language': 'en', 'value': 'Scotland'}, 'fr': {'language': 'fr', 'value': 'Écosse'}, 'it': {'language': 'it', 'value': 'Scozia'}, 'pl': {'language': 'pl', 'value': 'Szkocja'}, 'eo': {'language': 'eo', 'value': 'Skotlando'}, 'nb': {'language': 'nb', 'value': 'Skottland'}, 'de': {'language': 'de', 'value': 'Schottland'}, 'ru': {'language': 'ru', 'value': 'Шотландия'}, 'ja': {'language': 'ja', 'value': 'スコットランド'}, 'zh-hant': {'language': 'zh-hant', 'value': '蘇格蘭'}, 'es': {'language': 'es', 'value': 'Escocia'}, 'en-ca': {'language': 'en-ca', 'value': 'Scotland'}, 'nl': {'language': 'nl', 'value': 'Schotland'}, 'mk': {'language': 'mk', 'value': 'Шкотска'}, 'br': {'language': 'br', 'value': 'Bro-Skos'}, 'af': {'language': 'af', 'value': 'Skotland'}, 'an': {'language': 'an', 'value': 'Escocia'}, 'ang': {'language': 'ang', 'value': 'Scotland'}, 'ar': {'language': 'ar', 'value': 'اسكتلندا'}, 'arz': {'language': 'arz', 'value': 'سكوتلاند'}, 'ast': {'language': 'ast', 'value': 'Escocia'}, 'az': {'language': 'az', 'value': 'Şotlandiya'}, 'bar': {'language': 'bar', 'value': 'Schottland'}, 'be': {'language': 'be', 'value': 'Шатландыя'}, 'bg': {'language': 'bg', 'value': 'Шотландия'}, 'bn': {'language': 'bn', 'value': 'স্কটল্যান্ড'}, 'bo': {'language': 'bo', 'value': 'སི་ཁོ་ཁྲི་ལན་ཌི།'}, 'bs': {'language': 'bs', 'value': 'Škotska'}, 'ca': {'language': 'ca', 'value': 'Escòcia'}, 'cdo': {'language': 'cdo', 'value': 'Sŭ-gáik-làng'}, 'ckb': {'language': 'ckb', 'value': 'سکۆتلاند'}, 'cs': {'language': 'cs', 'value': 'Skotsko'}, 'csb': {'language': 'csb', 'value': 'Szkòckô'}, 'cv': {'language': 'cv', 'value': 'Шотланди'}, 'cy': {'language': 'cy', 'value': 'Yr Alban'}, 'da': {'language': 'da', 'value': 'Skotland'}, 'diq': {'language': 'diq', 'value': 'İskoçya'}, 'dsb': {'language': 'dsb', 'value': 'Šotiska'}, 'el': {'language': 'el', 'value': 'Σκωτία'}, 'et': {'language': 'et', 'value': 'Šotimaa'}, 'eu': {'language': 'eu', 'value': 'Eskozia'}, 'ext': {'language': 'ext', 'value': 'Escócia'}, 'fa': {'language': 'fa', 'value': 'اسکاتلند'}, 'fi': {'language': 'fi', 'value': 'Skotlanti'}, 'fo': {'language': 'fo', 'value': 'Skotland'}, 'fy': {'language': 'fy', 'value': 'Skotlân'}, 'ga': {'language': 'ga', 'value': 'Albain'}, 'gd': {'language': 'gd', 'value': 'Alba'}, 'gl': {'language': 'gl', 'value': 'Escocia'}, 'gv': {'language': 'gv', 'value': 'Nalbin'}, 'hak': {'language': 'hak', 'value': 'Sû-kak-làn'}, 'he': {'language': 'he', 'value': 'סקוטלנד'}, 'hi': {'language': 'hi', 'value': 'स्कॉटलैण्ड'}, 'hr': {'language': 'hr', 'value': 'Škotska'}, 'hsb': {'language': 'hsb', 'value': 'Šotiska'}, 'ht': {'language': 'ht', 'value': 'Ekòs'}, 'hu': {'language': 'hu', 'value': 'Skócia'}, 'hy': {'language': 'hy', 'value': 'Շոտլանդիա'}, 'ia': {'language': 'ia', 'value': 'Scotia'}, 'id': {'language': 'id', 'value': 'Skotlandia'}, 'ie': {'language': 'ie', 'value': 'Scotia'}, 'ilo': {'language': 'ilo', 'value': 'Eskosia'}, 'io': {'language': 'io', 'value': 'Skotia'}, 'is': {'language': 'is', 'value': 'Skotland'}, 'jv': {'language': 'jv', 'value': 'Skotlandia'}, 'ka': {'language': 'ka', 'value': 'შოტლანდია'}, 'kaa': {'language': 'kaa', 'value': 'Shotlandiya'}, 'kk': {'language': 'kk', 'value': 'Шотландия'}, 'km': {'language': 'km', 'value': 'ស្កុតឡែន'}, 'kn': {'language': 'kn', 'value': 'ಸ್ಕಾಟ್ ಲ್ಯಾಂಡ್'}, 'ko': {'language': 'ko', 'value': '스코틀랜드'}, 'krc': {'language': 'krc', 'value': 'Шотландия'}, 'ksh': {'language': 'ksh', 'value': 'Schottland'}, 'ku': {'language': 'ku', 'value': 'Skotland'}, 'kv': {'language': 'kv', 'value': 'Шотландия'}, 'kw': {'language': 'kw', 'value': 'Alban'}, 'la': {'language': 'la', 'value': 'Scotia'}, 'lad': {'language': 'lad', 'value': 'Eskosia'}, 'lb': {'language': 'lb', 'value': 'Schottland'}, 'li': {'language': 'li', 'value': 'Sjotland'}, 'lij': {'language': 'lij', 'value': 'Scòçia'}, 'lmo': {'language': 'lmo', 'value': 'Scozia'}, 'ln ...

# %% [markdown]
# ## Comment extraire une partie des données ?
#
# Ici, nous avons fabriqué deux fonctions pour extraire le label et une propriété.

# %%
import json

wikiFile = sc.textFile('wikidata-sample.json')

def extractProperty(entity, prop):
    try: return entity.get('claims').get(prop)[0].get('mainsnak').get('datavalue').get('value').get('id') 
    except: return ''
    
def extractLabel(entity, lang):
    try: return entity.get('labels').get(lang).get('value')
    except: return ''

rddExtractWikidata = wikiFile \
  .filter(lambda x: '{' in x) \
  .map(lambda x: json.loads(x[:-1])) \
  .map(lambda x: ( int(x.get('id')[1:]),   
                      {
                          'id' : x.get('id'),
                          'label_en': extractLabel(x,'en') ,
                           'P734': extractProperty(x, 'P734')
                      }
                 )\
       )  
    
print(rddExtractWikidata.take(5))
# Out:
# [(22, {'id': 'Q22', 'label_en': 'Scotland', 'P734': ''}), (31, {'id': 'Q31', 'label_en': 'Belgium', 'P734': ''}), (1, {'id': 'Q1', 'label_en': 'universe', 'P734': ''}), (13, {'id': 'Q13', 'label_en': 'triskaidekaphobia', 'P734': ''}), (23, {'id': 'Q23', 'label_en': 'George Washington', 'P734': 'Q2550388'})]

# %% [markdown]
# ## Comment remplacer un ID par son label dans un RDD ?
#
# On commence par fabriquer un RDD qui contiendra uniquement les entités qui possédent la propriété qui nous intéresse afin de réduire le nombre d'entités.
#
# On remplace la clé pour l'id que l'on cherche à résoudre.

# %%
def changeKey(x,newKey):
    K, V = x
    if V[newKey] == '' :
        return []
    else:        
        return [(int(V[newKey][1:]), V)]

rddP734 =  rddExtractWikidata.flatMap(lambda x: changeKey(x,'P734'))
print(rddP734.take(5))
# Out:
# [(2550388, {'id': 'Q23', 'label_en': 'George Washington', 'P734': 'Q2550388'}), (18375255, {'id': 'Q306', 'label_en': 'Sebastián Piñera', 'P734': 'Q18375255'}), (16871131, {'id': 'Q400', 'label_en': 'Jenna Jameson', 'P734': 'Q16871131'}), (18371366, {'id': 'Q449', 'label_en': 'Georges Brassens', 'P734': 'Q18371366'}), (18368860, {'id': 'Q464', 'label_en': 'Philipp Ludwig von Seidel', 'P734': 'Q18368860'})]

# %% [markdown]
# Maintenant, on fabrique un autre RDD qui n'aura que son ID et un label avec un nom d'attribut adapté.

# %%
rddLabel = rddExtractWikidata.mapValues(lambda v: 
                              {'P734_Label_en': v['label_en']}
                          )
print(rddLabel.take(5))
# Out:
# [(22, {'P734_Label_en': 'Scotland'}), (31, {'P734_Label_en': 'Belgium'}), (1, {'P734_Label_en': 'universe'}), (13, {'P734_Label_en': 'triskaidekaphobia'}), (23, {'P734_Label_en': 'George Washington'})]

# %% [markdown]
# On fait maintenant une jointure pour obtenir toutes les informations qui nous permettra de fabriquer une vue utilisable.

# %%
#And finally the join
rddJoinP734 = rddP734.join(rddLabel)
print(rddJoinP734.take(5))
# Out:
# [(2550388, ({'id': 'Q23', 'label_en': 'George Washington', 'P734': 'Q2550388'}, {'P734_Label_en': 'Washington'}))]

# %% [markdown]
# ## Comment sauvegarder mes données dans un CSV ?
#
# Pour sauvegarder un RDD, on peut passer par un DataFrame pour le faire simplement.

# %%
#Organize header of CSV
rddForDataFrame = rddJoinP734.map(lambda x:  
                                       Row(                                           
                                           idWikidata=x[1][0]["id"], 
                                           label_en=x[1][0]["label_en"], 
                                           P734=x[1][0]["P734"], 
                                           P734_Label_en=x[1][1]["P734_Label_en"]
                                          )
                                      )
#Create the dataframe
df = spark.createDataFrame(rddForDataFrame)

#Save the dataframe 
#in one file
df.coalesce(1).write.csv('rddForDataFrameCSV',header=True)
#df.write.csv('folderOfMyFileCSV',header=True)
